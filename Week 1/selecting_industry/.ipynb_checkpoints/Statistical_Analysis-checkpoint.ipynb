# %%
#!pip install yfinance
import yfinance as yf
import pandas as pd
import csv
import glob
import os
import matplotlib.pyplot as plt
import numpy as np
import statistics
from datetime import datetime, timedelta

# %% [markdown]
# open csv file and save it as a dictionary

# %%
csv_file = 'filtered_stock.csv'

data = {}

# Read data from the CSV file
with open(csv_file, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    
    for row in reader:
        key = row['Key']
        values = row['Values'].split(', ')  # Split the values by commas
        data[key] = values
        
# Now 'data' contains the dictionary you originally wrote to the CSV file
print(data.keys())
# Out:
# dict_keys(['transportation', 'materials', 'consumer-services', 'energy', 'pharmaceuticals-biotech', 'healthcare', 'consumer-retailing', 'real-estate', 'capital-goods', 'retail', 'software', 'utilities', 'food-beverage-tobacco', 'telecom', 'automobiles', 'diversified-financials', 'consumer-durables', 'household', 'tech', 'banks', 'insurance', 'semiconductors', 'commercial-services', 'media'])

# %% [markdown]
# Fetch the earning call dates for each companies

# %%
raw_earn_dict = {}

for inds in data:
    file_loc = '../sectors/' + inds 
    
    for cmp in data[inds]:
        folder_names = glob.glob(file_loc + '/' + cmp + '/*') #folder_names contain name of all earnings call files of the selected company
        
        for name in folder_names:
            if 'names' in name:
                folder_names.remove(name) #remove the file with presentor names
                
        raw_earn_dates = []
        
        for earn_logs in folder_names:
            file = open(earn_logs, encoding='utf8') #added encoding = 'utf8' because my OS is in Korean
            earn_log = csv.reader(file)
            next(earn_log)
            next(earn_log)
            earn_date = next(earn_log) #get the earnings call date and time            
            raw_earn_dates.append(earn_date)
            
        if(len(folder_names) != len(raw_earn_dates)):
            print('error')
            
        raw_earn_dict[cmp] = raw_earn_dates #append earn-dates to dictionary earn_dict with key being the company name and element being earnings call dates

raw_earn_dict['SCHN.SW'] = raw_earn_dict.pop('SCHN')

print(raw_earn_dict.keys(), len(raw_earn_dict.keys()))
# Out:
# dict_keys(['SB', 'ULCC', 'PANL', 'AAL', 'RLGT', 'GNK', 'CAR', 'ARCB', 'CPA', 'DSKE', 'FWRD', 'WERN', 'TSP', 'SBLK', 'XPO', 'LYFT', 'SNCY', 'ULH', 'SKYW', 'JOBY', 'R', 'GOGL', 'ALK', 'KEX', 'ALGT', 'CHRW', 'LSTR', 'ZIM', 'NETI', 'KNX', 'UP', 'GSL', 'CMRE', 'HA', 'SNDR', 'YMM', 'HUBG', 'EGLE', 'DAC', 'GXO', 'SAVE', 'UHAL', 'MATX', 'JBLU', 'ATSG', 'DSX', 'CAAP', 'CVLG', 'CDE', 'AMR', 'CMC', 'PCT', 'LXU', 'DRD', 'CMP', 'CBT', 'EMN', 'AXTA', 'BERY', 'TROX', 'NEXA', 'HAYN', 'BIOX', 'SMG', 'HL', 'MUX', 'NEU', 'IPI', 'TRS', 'SLGN', 'PTVE', 'RYI', 'KRO', 'TSE', 'SEE', 'VVV', 'SXT', 'CCK', 'PACK', 'CLF', 'GEF', 'BVN', 'LPX', 'MERC', 'HUN', 'CENX', 'OEC', 'BCPC', 'KOP', 'TX', 'MTRN', 'ECVT', 'IOSP', 'LOMA', 'KALU', 'CSTM', 'SUM', 'SLVM', 'AMBP', 'AVD', 'MYE', 'MP', 'GSM', 'ASPN', 'HCC', 'AA', 'GPK', 'ESI', 'TMST', 'ASH', 'RGLD', 'SCL', 'ATR', 'CC', 'CRS', 'ATI', 'KWR', 'FF', 'FMC', 'DNA', 'WOR', 'AVNT', 'EXP', 'OI', 'MTX', 'OLN', 'CLW', 'NGVT', 'MATV', 'X', 'LTHM', 'SXC', 'ZEUS', 'WRK', 'ASIX', 'FUL', 'TMC', 'METC', 'DENN', 'LRN', 'ADT', 'CHUY', 'CHH', 'PTLO', 'AGS', 'GHG', 'DESP', 'OSW', 'ARCE', 'NCLH', 'SHAK', 'NRDY', 'TAST', 'CZR', 'FRGI', 'RICK', 'TXRH', 'RSI', 'PZZA', 'BJRI', 'SCI', 'INSE', 'ARMK', 'MTN', 'STRA', 'DAO', 'BYD', 'VTRU', 'PRDO', 'ROVR', 'EWCZ', 'PLYA', 'MCW', 'TAL', 'UTI', 'WW', 'CBRL', 'LIND', 'MMYT', 'LINC', 'PENN', 'HRB', 'BFAM', 'EAT', 'MLCO', 'IGT', 'EVRI', 'BLMN', 'LAUR', 'DIN', 'CSV', 'KRUS', 'ARCO', 'BALY', 'CHDN', 'LOPE', 'FTDR', 'JACK', 'RRR', 'CHGG', 'VSTA', 'AFYA', 'NGMS', 'ATGE', 'HGV', 'NAAS', 'DUOL', 'WEN', 'SIX', 'ACEL', 'PLAY', 'BROS', 'COUR', 'GDEN', 'PLNT', 'PBPB', 'GENI', 'LOCO', 'UDMY', 'TH', 'WING', 'VAC', 'CAKE', 'SEAS', 'TNL', 'DNUT', 'WH', 'MGY', 'STNG', 'PTEN', 'CNX', 'ETRN', 'RES', 'SM', 'CEIX', 'FRO', 'EVA', 'CLNE', 'HP', 'AM', 'XPRO', 'NOG', 'WHD', 'RRC', 'DEN', 'REGI', 'GPRE', 'CRK', 'ESTE', 'INSW', 'NBR', 'CRC', 'GPOR', 'HPK', 'CHRD', 'TALO', 'CHX', 'BTU', 'RIG', 'ENLC', 'FTI', 'LBRT', 'DTM', 'MUR', 'CVI', 'ARCH', 'GLNG', 'AR', 'CPE', 'NFE', 'NE', 'NOV', 'HESM', 'NEX', 'DK', 'MTDR', 'RTLR', 'PBF', 'KOS', 'SWN', 'WFRD', 'MRTX', 'TLRY', 'IRWD', 'ARWR', 'AMPH', 'TWST', 'OGN', 'SRPT', 'TVTX', 'BIO', 'BPMC', 'SNDX', 'IMGN', 'SHC', 'RVMD', 'CERE', 'TXG', 'RGEN', 'NEO', 'CLDX', 'RYTM', 'STVN', 'MEDP', 'RVNC', 'TGTX', 'SYNH', 'BHC', 'CRL', 'INSM', 'CPRX', 'ADPT', 'PACB', 'MRVI', 'HALO', 'CTLT', 'SUPN', 'NTRA', 'PRGO', 'VCYT', 'XENE', 'FATE', 'ABCL', 'CTKB', 'CYTK', 'MYGN', 'LGND', 'BCRX', 'IOVA', 'ZLAB', 'PTCT', 'RETA', 'RARE', 'ASND', 'ALLO', 'EXEL', 'NVAX', 'APLS', 'IONS', 'CORT', 'ACAD', 'ITCI', 'TEVA', 'XNCR', 'BRKR', 'FOLD', 'BEAM', 'QGEN', 'NTLA', 'AGIO', 'PCRX', 'TECH', 'DVAX', 'ACRS', 'AXSM', 'HRMY', 'ELAN', 'ALKS', 'PBH', 'SAGE', 'JAZZ', 'NVST', 'ICUI', 'AMN', 'AHCO', 'NRC', 'PODD', 'PRCT', 'TFX', 'MASI', 'OMCL', 'OMI', 'GKOS', 'RCM', 'HIMS', 'QDEL', 'IRTC', 'EHC', 'NARI', 'GMED', 'CCRN', 'GH', 'EVH', 'TDOC', 'UHS', 'MODV', 'USPH', 'LIVN', 'SGRY', 'DH', 'ATEC', 'PDCO', 'MPLN', 'OPK', 'ENSG', 'FIGS', 'HAE', 'AMEH', 'SEM', 'SLP', 'SWAV', 'ACCD', 'AXNX', 'OM', 'INSP', 'PRVA', 'BKD', 'SHCR', 'HSIC', 'SENS', 'OPCH', 'ALHC', 'DOCS', 'LFST', 'TMCI', 'THC', 'AGTI', 'PEN', 'RDNT', 'SILK', 'ATRC', 'CSTL', 'LMAT', 'PGNY', 'LNTH', 'PINC', 'HQY', 'STAA', 'MMSI', 'FLGT', 'CHE', 'AGL', 'TMDX', 'MDRX', 'ME', 'CNMD', 'CERT', 'NXGN', 'CERS', 'ACHC', 'CRVL', 'MD', 'NEOG', 'SDGR', 'NUVA', 'VREX', 'ESTA', 'ITGR', 'CLOV', 'NVCR', 'AVNS', 'ADUS', 'TNDM', 'AMED', 'GDRX', 'KIDS', 'DVA', 'HSTM', 'ANGO', 'INMD', 'IART', 'INNV', 'XRAY', 'AMWL', 'NNOX', 'NVRO', 'GO', 'BJ', 'CHEF', 'SFM', 'PFGC', 'ANDE', 'NGVC', 'UNFI', 'PSMT', 'SPTN', 'USFD', 'LAND', 'PCH', 'SAFE', 'BRT', 'ALEX', 'PK', 'FRT', 'LTC', 'NMRK', 'GNL', 'EPRT', 'DBRG', 'UNIT', 'REXR', 'PEB', 'APLE', 'CPT', 'CSR', 'DEA', 'OUT', 'DEI', 'KW', 'RYN', 'RPT', 'CTRE', 'NHI', 'CUBE', 'KRG', 'BDN', 'ESRT', 'HPP', 'OFC', 'EXPI', 'NSA', 'SBRA', 'XHR', 'COMP', 'RDFN', 'AIRC', 'ALX', 'STAG', 'ZG', 'SVC', 'BXP', 'MAC', 'IIPR', 'EGP', 'AAT', 'NTST', 'LXP', 'INN', 'FRPH' ...

# %% [markdown]
# Modify the date to accommodate the time

# %%
date_format_full = '%Y-%m-%d %H:%M:%S'
count = 0
earn_dict = {}

for inds in data:
    
    for cmp in data[inds]:
        earn_dates = []
        if cmp == 'SCHN':
            cmp = 'SCHN.SW'
        for earn_date in raw_earn_dict[cmp]:
            datetime_earn_date = datetime.strptime(earn_date[0], date_format_full)
            datetime_earn_open = datetime_earn_date.replace(hour = 9, minute = 30)
            datetime_earn_close = datetime_earn_date.replace(hour = 16, minute = 0)
            
            if datetime_earn_open < datetime_earn_date and datetime_earn_date < datetime_earn_close:
                #print(cmp + ' in industry ' + inds + ', earnings call happened during marekt time. date: ' + str(datetime_earn_date))
                count += 1 # check if earnings call was happened during market time
                
            elif datetime_earn_date < datetime_earn_open:
                datetime_earn_date -= timedelta(days=1)
                #print('change to date, new date is :' + str(datetime_earn_date))
                # check if earnings call was happened before market open time
                
                earn_dates.append(str(datetime_earn_date.date())) #append the dates to earn_dates
            
            else:
                earn_dates.append(str(datetime_earn_date.date())) #append the dates to earn_dates
            
        if(len(earn_dates) != 0):
            earn_dict[cmp] = earn_dates

for cmp in earn_dict.keys():
    print(cmp, len(earn_dict[cmp]))
# Out:
# SB 29
# ULCC 5
# PANL 21
# AAL 26
# RLGT 29
# GNK 29
# CAR 50
# ARCB 35
# CPA 41
# DSKE 15
# FWRD 35
# WERN 12
# TSP 5
# SBLK 49
# XPO 33
# LYFT 15
# SNCY 6
# ULH 15
# SKYW 39
# JOBY 5
# R 52
# GOGL 16
# ALK 41
# KEX 37
# ALGT 39
# CHRW 54
# LSTR 46
# ZIM 2
# NETI 1
# KNX 17
# UP 5
# GSL 32
# CMRE 27
# HA 39
# SNDR 18
# YMM 1
# HUBG 35
# EGLE 18
# DAC 29
# SAVE 32
# UHAL 32
# MATX 40
# JBLU 54
# ATSG 35
# DSX 48
# CAAP 7
# CVLG 4
# CDE 54
# AMR 4
# CMC 48
# PCT 4
# LXU 35
# DRD 5
# CMP 41
# CBT 40
# EMN 47
# AXTA 24
# BERY 38
# TROX 33
# NEXA 2
# HAYN 28
# BIOX 4
# SMG 40
# HL 53
# MUX 25
# NEU 38
# IPI 50
# TRS 37
# SLGN 42
# PTVE 1
# RYI 25
# KRO 5
# TSE 25
# SEE 55
# VVV 17
# SXT 32
# CCK 44
# PACK 3
# CLF 48
# GEF 39
# BVN 25
# SCHN.SW 41
# LPX 55
# MERC 37
# HUN 54
# CENX 58
# OEC 23
# BCPC 40
# KOP 35
# TX 26
# MTRN 35
# ECVT 5
# IOSP 32
# LOMA 7
# KALU 40
# CSTM 29
# SUM 20
# SLVM 3
# AMBP 3
# AVD 38
# MYE 29
# MP 8
# GSM 31
# ASPN 29
# HCC 36
# AA 60
# GPK 53
# ESI 17
# TMST 21
# ASH 40
# RGLD 39
# SCL 33
# ATR 40
# CC 18
# CRS 52
# ATI 51
# KWR 32
# FF 12
# FMC 46
# DNA 5
# WOR 35
# AVNT 2
# EXP 32
# OI 45
# MTX 37
# OLN 53
# CLW 36
# NGVT 19
# MATV 31
# X 46
# LTHM 15
# SXC 29
# ZEUS 51
# WRK 36
# ASIX 13
# FUL 33
# TMC 5
# METC 13
# DENN 44
# LRN 38
# ADT 20
# CHUY 34
# CHH 41
# PTLO 2
# AGS 16
# GHG 12
# DESP 10
# OSW 3
# ARCE 13
# NCLH 30
# SHAK 26
# NRDY 5
# TAST 51
# CZR 40
# FRGI 37
# RICK 38
# TXRH 40
# RSI 7
# PZZA 32
# BJRI 40
# SCI 47
# INSE 4
# ARMK 24
# MTN 38
# STRA 41
# DAO 5
# BYD 58
# VTRU 8
# PRDO 45
# ROVR 5
# EWCZ 4
# PLYA 12
# MCW 3
# TAL 24
# UTI 35
# WW 57
# CBRL 36
# LIND 22
# MMYT 21
# LINC 31
# PENN 43
# HRB 46
# BFAM 37
# EAT 40
# MLCO 34
# IGT 48
# EVRI 37
# BLMN 27
# LAUR 18
# DIN 35
# CSV 36
# KRUS 10
# ARCO 28
# BALY 1
# CHDN 33
# LOPE 37
# FTDR 13
# JACK 59
# RRR 23
# CHGG 34
# VSTA 6
# AFYA 11
# NGMS 2
# ATGE 49
# HGV 15
# NAAS 9
# DUOL 5
# WEN 39
# SIX 44
# ACEL 3
# PLAY 24
# BROS 5
# COUR 6
# GDEN 34
# PLNT 23
# PBPB 31
# LOCO 27
# UDMY 4
# TH 4
# WING 25
# VAC 32
# CAKE 59
# SEAS 29
# TNL 3
# DNUT 2
# WH 8
# MGY 11
# STNG 30
# PTEN 42
# CNX 51
# ETRN 2
# RES 40
# SM 39
# CEIX 17
# FRO 47
# EVA 22
# CLNE 53
# HP 45
# AM 34
# XPRO 4
# NOG 37
# WHD 12
# RRC 50
# DEN 7
# REGI 33
# GPRE 47
# CRK 58
# ESTE 22
# INSW 10
# NBR 58
# CRC 3
# GPOR 33
# HPK 1
# CHRD 35
# TALO 30
# CHX 3
# BTU 42
# RIG 52
# ENLC 7
# FTI 45
# LBRT 15
# MUR 49
# CVI 55
# ARCH 37
# GLNG 34
# AR 29
# CPE 33
# NFE 9
# NOV 53
# HESM 16
# NEX 3
# DK 40
# MTDR 34
# RTLR 6
# PBF 30
# KOS 40
# SWN 53
# WFRD 1
# MRTX 5
# TLRY 8
# IRWD 33
# ARWR 42
# AMPH 32
# TWST 10
# SRPT 36
# TVTX 5
# BIO 43
# BPMC 13
# SNDX 21
# IMGN 33
# SHC 4
# RVMD 6
# CERE 1
# TXG 9
# RGEN 34
# NEO 32
# CLDX 5
# RYTM 1
# STVN 1
# MEDP 14
# RVNC 29
# TGTX 26
# SYNH 21
# BHC 34
# CRL 43
# INSM 22
# CPRX 14
# ADPT 17
# PACB 28
# MRVI 7
# HALO 41
# CTLT 19
# SUPN 35
# NTRA 22
# PRGO 34
# VCYT 33
# XENE 24
# FATE 32
# ABCL 8
# CTKB 5
# CYTK 38
# MYGN 43
# LGND 37
# BCRX 34
# IOVA 23
# ZLAB 3
# PTCT 33
# RETA 11
# RARE 26
# ASND 24
# ALLO 14
# EXEL 58
# NVAX 40
# APLS 8
# IONS 51
# CORT 35
# ACAD 41
# ITCI 13
# TEVA 50
# XNCR 33
# BRKR 44
# FOLD 34
# BEAM 25
# QGEN 36
# NTLA 6
# AGIO 28
# PCRX 31
# TECH 26
# DVAX 16
# ACRS 11
# AXSM 11
# HRMY 1
# ELAN 7
# ALKS 32
# PBH 33
# SAGE 18
# JAZZ 41
# NVST 11
# ICUI 37
# AMN 36
# AHCO 3
# NRC 26
# PODD 37
# PRCT 4
# TFX 42
# MASI 55
# OMCL 36
# OMI 34
# GKOS 23
# RCM 23
# HIMS 6
# QDEL 54
# IRTC 21
# EHC 35
# NARI 9
# GMED 38
# CCRN 36
# GH 15
# EVH 24
# TDOC 24
# UHS 39
# MODV 3
# USPH 32
# LIVN 21
# SGRY 21
# DH 5
# ATEC 30
# PDCO 49
# MPLN 1
# OPK 32
# ENSG 37
# FIGS 6
# HAE 30
# AMEH 6
# SEM 31
# SLP 38
# SWAV 12
# ACCD 10
# AXNX 13
# OM 6
# INSP 14
# PRVA 2
# BKD 35
# HSIC 52
# SENS 24
# OPCH 2
# ALHC 4
# DOCS 5
# LFST 4
# TMCI 3
# THC 54
# AGTI 3
# PEN 23
# RDNT 35
# SILK 9
# ATRC 55
# CSTL 10
# LMAT 49
# PGNY 11
# LNTH 26
# PINC 26
# HQY 32
# STAA 41
# MMSI 38
# FLGT 21
# CHE 33
# AGL 3
# TMDX 10
# MDRX 49
# ME 5
# CNMD 38
# CERT 8
# NXGN 38
# CERS 39
# ACHC 31
# CRVL 23
# MD 40
# NEOG 49
# SDGR 6
# NUVA 41
# VREX 20
# ESTA 11
# ITGR 35
# CLOV 7
# NVCR 17
# AVNS 24
# ADUS 30
# TNDM 29
# AMED 40
# GDRX 7
# KIDS 14
# DVA 56
# HSTM 34
# ANGO 51
# INMD 3
# IART 34
# INNV 6
# XRAY 52
# AMWL 9
# NVRO 26
# GO 12
# BJ 8
# CHEF 29
# SFM 33
# PFGC 18
# ANDE 38
# NGVC 36
# UNFI 31
# PSMT 32
# SPTN 29
# USFD 17
# LAND 27
# PCH 40
# SAFE 14
# BRT 2
# ALEX 44
# PK 20
# FRT 42
# LTC 37
# NMRK 9
# GNL 23
# EPRT 12
# DBRG 1
# UNIT 21
# REXR 31
# PEB 36
# APLE 20
# CPT 47
# CSR 3
# DEA 17
# OUT 32
# DEI 44
# KW 35
# RYN 49
# RPT 50
# CTRE 29
# NHI 34
# CUBE 36
# KRG 38
# BDN 54
# ESRT 32
# HPP 35
# OFC 46
# EXPI 5
# NSA 23
# SBRA 38
# XHR 28
# COMP 7
# RDFN 20
# AIRC 5
# ALX 4
# STAG 32
# ZG 9
# SVC 51
# BXP 52
# MAC 58
# IIPR 10
# EGP 37
# AAT 30
# NTST 1
# LXP 34
# INN 32
# FRPH 10
# CBL 49
# OHI 36
# WSR 30
# LAMR 38
# AKR 36
# DRH 50
# BRX 28
# PEAK 49
# ADC 33
# AHH 27
# MMI 28
# COLD 17
# GOOD 32
# RLJ 30
# OPI 5
# SITC 48
# HT 34
# UMH 30
# JLL 48
# HIW 36
# CUZ 37
# CLDT 33
# SKT 34
# EPR 36
# SHO 52
# HR 24
# JOE 11
# ROIC 36
# FOR 23
# GMRE 7
# MPW 54
# DOC 27
# HOUS 31
# NNN 37
# FR 54
# IRT 23
# GTY 38
# CWK 10
# BNL 5
# CHCT 15
# KRC 38
# SLG 55
# EQC 33
# RMAX 21
# PGRE 24
# NXRT 15
# FPI 27
# RMR 20
# OPEN 8
# PECO 5
# PLYM 9
# RHP 34
# FCPT 18
# AIV 45
# SRC 31
# PDM 39
# VNO 31
# ARRY 8
# CSWI 17
# SSD 38
# ALLE 27
# WSC 12
# KMT 49
# TREX 39
# HRI 9
# CHPT 6
# ENS 35
# CNM 1
# TEX 51
# WMS 23
# TRN 47
# BE 15
# OSK 52
# ESE 35
# HII 36
# WIRE 50
# AL 44
# AZEK 6
# RKLB 5
# TTC 40
# MTZ 52
# UFPI 38
# ENVX 6
# LNN 54
# CR 41
# ITT 50
# JBT 29
# AIT 34
# ACA 7
# AMRC 40
# GTES 14
# WWD 39
# PNR 44
# NPO 32
# GTLS 39
# STEM 6
# AIN 30
# ST 30
# GMS 15
# HXL 37
# MDU 54
# EME 34
# KAI 34
# SPR 42
# AYI 33
# FLR 47
# DCI 35
# MRCY 42
# GATX 46
# FIX 36
# BECN 37
# FELE 31
# FLS 56
# DY 29
# HAYW 2
# MSM 36
# MIDD 38
# BCC 36
# SITE 15
# VICR 35
# HI 34
# TRTN 36
# APG 2
# BWXT 41
# AVAV 41
# SHLS 6
# NVEE 31
# AAON 36
# ATKR 12
# PSN 6
# WCC 39
# CW 36
# RUN 24
# SPXC 56
# AGCO 41
# ALSN 37
# AWI 38
# SPWR 52
# FSS 34
# PLUG 35
# MGRC 37
# WTS 35
# GNRC 36
# TKR 43
# NVT 9
# REZI 14
# B 33
# IEP 29
# VMI 42
# ALG 30
# GME 68
# AAP 49
# DADA 7
# ANF 54
# CRMT 30
# OSTK 47
# DXLG 31
# HIBB 33
# WSM 52
# CHS 39
# JWN 67
# EYE 13
# GPI 34
# BOOT 29
# PLCE 28
# MNRO 29
# GPS 67
# LQDT 34
# SNBR 54
# FLWS 38
# CWH 15
# ARKO 5
# LAD 37
# BKE 30
# XMTR 3
# SIG 37
# SCVL 34
# LE 21
# DBI 37
# TTSH 4
# DKS 39
# BBW 51
# FL 45
# VIPS 29
# ZUMZ 41
# GES 45
# FVRR 4
# TLYS 39
# ETSY 29
# RH 39
# HVT 31
# CAL 39
# FNKO 17
# ABG 36
# AAN 40
# ODP 33
# MUSA 33
# AN 55
# JMIA 6
# SAH 53
# KSS 51
# GRPN 35
# JILL 9
# BURL 26
# SBH 39
# LESL 7
# FND 20
# MNSO 2
# SFIX 20
# URBN 53
# FTCH 16
# BRLT 4
# RVLV 8
# EVGO 4
# CTRN 25
# ONEW 3
# WEYS 32
# MYTE 1
# M 51
# TDUP 7
# HZO 46
# FIVE 35
# CHWY 13
# AEO 61
# GCO 32
# QUOT 24
# W 17
# DXC 54
# TENB 14
# ESMT 3
# CCCS 2
# GWRE 41
# AYX 20
# BOX 28
# BL 24
# BILL 10
# SPSC 36
# WNS 30
# DLO 2
# DAVA 10
# EXLS 35
# CFLT 5
# TWLO 24
# ACIW 34
# JAMF 10
# QLYS 41
# PATH 6
# CWAN 5
# CYBR 22
# WEX 56
# PCTY 31
# ESTC 16
# DOCU 18
# U 8
# SMAR 17
# DOCN 4
# OTEX 52
# G 44
# WK 30
# FIVN 32
# S 5
# PRGS 39
# EVTC 30
# PEGA 41
# MMS 32
# FRSH 5
# ENV 34
# PRFT 56
# SPT 11
# NEWR 30
# INFA 4
# PAGS 14
# STNE 10
# BLKB 33
# ASAN 5
# PWSC 4
# ALRM 24
# DV 5
# PAYC 34
# VRNT 30
# NCR 64
# AFRM 7
# NTNX 21
# FLYW 6
# ALTR 40
# DOX 50
# DLB 50
# MQ 6
# GLOB 29
# EEFT 34
# NCNO 6
# WIX 21
# YOU 1
# FROG 6
# DBX 19
# PYCR 3
# INST 6
# WU 60
# PCOR 5
# CVLT 34
# TDC 55
# APPF 27
# RNG 34
# SQSP 4
# APPN 19
# MNDY 1
# FOUR 1
# NWN 39
# OGS 28
# GNE 31
# HE 44
# MNTK 3
# NFG 37
# AY 18
# AVA 41
# CWT 39
# ORA 51
# WTRG 4
# NOVA 9
# RNW 1
# ALE 40
# SWX 38
# POR 57
# OGE 47
# IDA 36
# GWRS 19
# SR 36
# NWE 39
# CWCO 32
# CPK 27
# PCYO 12
# NJR 35
# UGI 36
# BKH 35
# OTTR 32
# SJW 36
# AWR 41
# UTL 33
# PNW 55
# PNM 47
# LANC 35
# LMNR 34
# STKL 35
# UVV 41
# POST 31
# TWNK 19
# JJSF 33
# SAM 40
# AVO 6
# DAR 31
# SOVO 3
# BGS 40
# PPC 34
# TPB 15
# INGR 37
# BYND 15
# MGPI 20
# VITL 3
# CVGW 10
# FRPT 30
# JBSS 33
# FLO 38
# FDP 34
# NOMD 15
# SMPL 12
# NAPA 6
# THS 33
# HAIN 31
# AGRO 26
# VGR 36
# TIGO 48
# CNSL 40
# LUMN 8
# ATEX 16
# GSAT 26
# ATNI 35
# RADI 2
# BAND 15
# TDS 34
# OOMA 20
# SPOK 28
# IDT 52
# SIFY 29
# CCOI 34
# SATS 34
# VEON 41
# SHEN 50
# IRDM 36
# ASTS 5
# GOGO 29
# LILA 5
# XPEL 24
# THRM 31
# WGO 33
# CPS 29
# GT 48
# DAN 38
# QS 8
# SRI 35
# GNTX 37
# ALV 37
# BWA 40
# FOXF 29
# VC 39
# HOG 46
# LEA 51
# KNDI 21
# SMP 33
# AXL 34
# GTX 5
# PATK 28
# MOD 35
# FSR 8
# ADNT 16
# VCTR 9
# OMF 24
# ECPG 38
# CACC 38
# AMG 39
# BRSP 1
# PJT 19
# ALLY 25
# AGNC 37
# PWP 3
# DFIN 15
# HASI 34
# RWT 30
# EVR 33
# BRDG 2
# BXMT 40
# LC 28
# EQH 12
# STWD 34
# JHG 14
# ARR 16
# HLNE 17
# ARI 30
# SLM 54
# APAM 30
# EFC 36
# STEP 7
# NAVI 25
# HTGC 42
# AMRK 27
# MFA 47
# PAX 1
# VRTS 30
# PMT 19
# CIM 26
# KREF 12
# NYMT 33
# UPST 7
# VIRT 22
# SEIC 47
# SOFI 5
# CNS 31
# ABR 49
# LADR 32
# SF 36
# QFIN 14
# BSIG 24
# RITM 22
# AMK 7
# CNNE 17
# FUTU 8
# PIPR 34
# MC 30
# TWO 30
# NLY 37
# HLI 22
# RILY 15
# LPRO 7
# IVZ 45
# FINV 13
# LU 7
# NNI 5
# GDOT 43
# ENVA 30
# SNEX 3
# FHI 1
# LAZ 36
# NOAH 39
# MAIN 33
# RC 15
# PRAA 39
# VOYA 30
# MKTX 33
# CODI 41
# MDC 39
# MHO 38
# TMHC 29
# GOLF 18
# GRBK 23
# SNPO 3
# MAT 60
# PII 41
# PTON 9
# HOV 58
# SKY 8
# SKX 39
# LOVE 8
# CLAR 36
# BC 57
# UAA 47
# BLD 20
# TPX 49
# VUZI 30
# VZIO 6
# LSEA 3
# MTH 46
# KTB 4
# JAKK 38
# PVH 38
# ETD 5
# CVCO 26
# LGIH 32
# JOUT 26
# CROX 48
# CRCT 7
# LZB 49
# WWW 31
# SONO 17
# VOXX 54
# MHK 55
# VFC 52
# KBH 58
# DTC 2
# COLM 40
# NWL 56
# IBP 30
# COOK 5
# LEVI 15
# SWIM 3
# MPX 33
# MODG 39
# WHR 52
# LEG 52
# VRA 30
# VSTO 15
# MCFT 12
# HAS 53
# OXM 37
# IRBT 52
# CPRI 33
# TPR 59
# HBI 39
# GPRO 36
# TPH 30
# CRI 38
# MBUU 23
# POWW 7
# SHOO 38
# SWBI 10
# RGR 21
# CCS 29
# BZH 42
# RL 51
# HELE 33
# YETI 8
# MOV 29
# SPB 42
# ENR 38
# SKIN 6
# OLPX 1
# EPC 17
# LFMD 7
# IPAR 34
# NATR 28
# ODC 47
# USNA 53
# HLF 46
# BRBR 6
# COTY 30
# WDFC 40
# REYN 4
# CENT 34
# ELF 20
# NUS 38
# MED 41
# ROG 33
# AUDC 30
# NNDM 10
# UI 25
# NSIT 38
# MASS 1
# CAN 5
# EXTR 52
# ARLO 13
# IMMR 44
# AVID 34
# AVT 46
# KE 13
# ADTN 55
# IONQ 5
# CMTL 37
# MVIS 41
# XRX 52
# NTGR 48
# LASR 13
# JNPR 61
# OSIS 40
# BMI 34
# IPGP 44
# LITE 18
# NSSC 30
# VSH 44
# VPG 29
# RDWR 33
# NTCT 35
# BHE 40
# AEIS 52
# CTS 32
# AVNW 38
# HOLI 31
# COMM 27
# NOVT 31
# COHR 30
# MEI 51
# FFIV 44
# CNXN 35
# DAKT 45
# NATI 59
# CALX 32
# GILT 43
# ITRI 51
# PLXS 30
# ITRN 28
# RBBN 56
# CIEN 57
# FARO 37
# INFN 52
# KN 31
# SNX 35
# HLIT 55
# EVLV 5
# SMRT 4
# CRSR 5
# SCSC 34
# FN 36
# AAOI 30
# ARW 52
# VIAV 52
# BDC 33
# DBD 47
# CLFD 18
# LFUS 30
# VSAT 36
# DGII 36
# TTMI 38
# KODK 42
# VNT 2
# SSYS 40
# PAR 34
# SANM 55
# PLUS 32
# CGNX 41
# PEBO 27
# CBU 31
# EWBC 55
# NBHC 30
# HOMB 38
# EBC 1
# HTLF 37
# PB 39
# PFC 4
# SSB 29
# HWC 14
# ESNT 29
# HFWA 33
# AX 13
# EGBN 29
# LOB 22
# BY 12
# BRKL 35
# ASB 45
# OZK 31
# RNST 31
# FCF 37
# PNFP 34
# WAL 39
# FHB 18
# FBP 30
# SBCF 32
# EFSC 30
# FIBK 30
# FBK 11
# VBTX 12
# LBAI 2
# CASH 18
# OSBC 29
# BOKF 27
# BANC 33
# NBTB 1
# MTG 37
# WSBC 34
# CNOB 17
# UVSP 22
# WD 31
# PPBI 31
# ACT 1
# CFR 44
# QCRH 18
# CADE 16
# WTFC 38
# NYCB 38
# ABCB 22
# OCFC 30
# STBA 35
# SBSI 21
# COLB 36
# PFS 31
# FFBC 42
# NTB 16
# FULT 56
# AGM 34
# CVBF 33
# HTH 21
# CMA 53
# TCBI 37
# COOP 11
# VLY 42
# ONB 35
# SFBS 30
# UCBI 34
# AUB 24
# WBS 35
# SFNC 28
# FRME 35
# UMBF 32
# ZION 61
# CATY 35
# SNV 40
# IBTX 25
# BOH 47
# NMIH 32
# WSFS 45
# AMAL 10
# HOPE 22
# TRST 27
# WASH 27
# GSBC 19
# SASR 35
# TBBK 41
# PFBC 44
# FFWM 3
# BANR 30
# FNB 35
# GBCI 34
# FHN 51
# BKU 33
# BPOP 36
# TRMK 32
# AMTB 1
# INDB 24
# OFG 31
# DCOM 5
# BHLB 29
# TFSL 15
# RDN 55
# HAFC 34
# AMSF 31
# UVE 27
# SPNT 2
# AGO 38
# MBI 49
# RLI 36
# GNW 39
# OSCR 7
# UNM 46
# PRA 35
# PRI 33
# HCI 34
# KMPR 38
# ORI 48
# HMN 34
# AXS 41
# GBLI 3
# AIZ 50
# EIG 29
# STC 19
# SLQT 4
# GLRE 53
# MCY 37
# AEL 34
# CNO 39
# BRP 14
# KNSL 13
# UFCS 29
# JRVR 19
# GOCO 8
# EHTH 37
# TIPT 22
# AMBC 26
# LNC 47
# GSHD 14
# BHF 11
# FAF 51
# PLMR 6
# ARGO 34
# TRUP 30
# FANH 40
# SIGI 34
# AFG 55
# THG 47
# RGA 44
# MKSI 35
# AOSL 29
# FORM 55
# AMKR 56
# CSIQ 34
# AMBA 36
# SLAB 52
# VECO 38
# SGH 19
# CRUS 46
# LSCC 53
# JKS 34
# ACLS 37
# OLED 56
# POWI 37
# SYNA 44
# RMBS 60
# MXL 38
# SEDG 24
# COHU 36
# QRVO 27
# ONTO 52
# MTSI 31
# INDI 6
# HIMX 35
# WOLF 5
# PI 24
# DQ 32
# SITM 9
# ACMR 10
# MX 27
# PDFS 35
# AEHR 53
# NVMI 46
# ICHR 19
# SMTC 38
# KLIC 41
# PLAB 31
# CEVA 46
# SKYT 3
# NVEC 52
# TSEM 34
# CAMT 29
# DIOD 47
# MAXN 7
# UCTT 39
# SIMO 32
# ALGM 4
# HQI 23
# MAN 41
# SP 34
# VSEC 6
# ABM 33
# ASGN 37
# CBZ 35
# QUAD 31
# BBSI 50
# FCN 56
# MSA 33
# TRU 20
# BCO 32
# BV 29
# WLDN 27
# SCS 52
# CXW 44
# FC 51
# HNI 57
# DNB 33
# GEO 35
# RHI 59
# KFY 36
# CLH 36
# HURN 37
# SRCL 52
# CWST 31
# TILE 31
# MEG 10
# EXPO 34
# HCCI 30
# RGP 10
# CACI 33
# UPWK 15
# CRAI 32
# KBR 50
# ACVA 7
# CLVT 4
# SAIC 30
# FORR 36
# KAR 37
# BRC 34
# TTEK 38
# DLX 55
# HCSG 23
# RDVT 9
# UNF 29
# TNET 32
# DRVN 3
# ACCO 49
# ICFI 35
# FA 1
# HSII 39
# CMPR 19
# LZ 6
# VVI 34
# NSP 37
# PBI 49
# KFRC 55
# CVEO 25
# STER 2
# MATW 31
# TBI 37
# YY 37
# TGNA 21
# EDR 7
# IAS 4
# CNK 32
# SSTK 31
# SSP 35
# NXST 50
# THRY 4
# SBGI 32
# EVER 19
# MGNI 8
# MYPS 5
# IMAX 43
# DISH 53
# TBLA 1
# PUBM 8
# AMCX 28
# OB 1
# BMBL 7
# EB 14
# WOW 11
# CDLX 17
# VTEX 4
# ATHM 27
# YELP 42
# TRVG 13
# GTN 49
# CABO 21
# NYT 57
# WWE 56
# WB 24
# EEX 15
# ATUS 18
# MAX 8
# STGW 1
# AMC 32
# HUYA 7
# PLTK 4
# ZIP 6
# ZH 2
# IAC 43
# ADV 6
# TRIP 27
# MOMO 22
# CARG 17
# BZ 1
# BILI 10
# DOYU 4
# MANU 30
# CARS 15
# EVC 36
# IHRT 10
# MTCH 12
# NCMI 38
# SCPL 5
# YALA 5
# CRTO 24
# IQ 10
# PERI 46
# QNST 35
# GCI 57
# CCO 33
# SOHU 60
# SCHL 57
# ANGI 23
# MCS 45
# FUBO 7
# TTGT 37

# %% [markdown]
# Check if there are no null values

# %%
for cmp in earn_dict.keys():
    if(len(earn_dict[cmp]) == 0):
        print(cmp, earn_dict[cmp])

# %%
print('total count of earnings call during market time: ' + str(count))
# Out:
# total count of earnings call during market time: 5264

# %% [markdown]
# Write the earning call date dictionary as csv file

# %%
csv_file = 'earning_call_dates.csv'

with open(csv_file, 'w', newline='') as csvfile:
    fieldnames = ['Key', 'Values']  # Define the CSV header
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    # Write the header row
    writer.writeheader()
    
    # Write data from the dictionary to the CSV
    for key, values in earn_dict.items():
        writer.writerow({'Key': key, 'Values': ', '.join(values)})

# %% [markdown]
# Open the earnings call date dictionary file

# %%
csv_file = 'earning_call_dates.csv'

earn_dict = {}

# Read data from the CSV file
with open(csv_file, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    
    for row in reader:
        key = row['Key']
        values = row['Values'].split(', ')  # Split the values by commas
        earn_dict[key] = values

# Now 'data' contains the dictionary you originally wrote to the CSV file

# %% [markdown]
# Create folders for each industires

# %%
if not os.path.exists('statistical_data'):
    os.mkdir('statistical_data')

for inds in data:
    if not os.path.exists('statistical_data/' + inds):
        os.mkdir('statistical_data/' + inds)
        
    for cmp in data[inds]:
        if cmp == 'SCHN':
            cmp = 'SCHN.SW'
        if not(cmp in earn_dict.keys()):
            continue
        if not os.path.exists('statistical_data/' + inds + '/' + cmp):
            os.mkdir('statistical_data/' + inds + '/' + cmp)

# %% [markdown]
# Create a dataframe for each company with stock prices for various dates

# %%
date_format = '%Y-%m-%d'
currwd = os.getcwd()

for inds in data:
    
    earn_impc_price = pd.DataFrame(columns = ['Day +1', 'Day +2', 'Day +7', 'Day +28', 'Day +63'])
    earn_impc_perc = pd.DataFrame(columns = ['Day +1', 'Day +2', 'Day +7', 'Day +28', 'Day +63'])
    #create two dataframes, one for recording average price gap and the other for recording avearge price percentage change.
    
    for cmp in data[inds]:
            
        print(inds, cmp)
        if cmp == 'SCHN':
            cmp = 'SCHN.SW'
        if not(cmp in earn_dict.keys()):
            continue
        
        price_df = pd.DataFrame(columns=['Day 0', 'Day +1', 'Day +2', 'Day +7', 'Day +28', 'Day +63'])
        price_gap = pd.DataFrame(columns=['Day +1', 'Day +2', 'Day +7', 'Day +28', 'Day +63'])
        price_perc = pd.DataFrame(columns=['Day +1', 'Day +2', 'Day +7', 'Day +28', 'Day +63'])
        #create three dataframes, one for tracking price data, one for tracking price gap, one for tracking price percentage change
        
        if(cmp == 'NEX' or cmp == 'NUVA' or cmp == 'QUOT' or cmp == 'WWE'):
            continue
            
        yfdata = yf.download(cmp) 
        yfdata_index = list(yfdata.index) # get the list of dates available from yfdata
        
        datetime_start_date = datetime.strptime(earn_dict[cmp][0], date_format) # mark the starting date from earnings call dates
        
        orig_count = len(earn_dict[cmp])
        remove_count = 0
        while(datetime_start_date < yfdata_index[0]):
            remove_count += 1
            earn_dict[cmp] = earn_dict[cmp][1:]
            # if the earliest earnings call date is before the earliest accessable stock price date, remove that date earnings call date
            
            if len(earn_dict[cmp]) == 0:
                # if there are no more earnings call date for this company, stop iteration
                break
                
            datetime_start_date = datetime.strptime(earn_dict[cmp][0], date_format)
            # get new start date to compare
            
            print('stock price not accessible in this date. Recalibrating start date to: ' + str(datetime_start_date))
            
        if len(earn_dict[cmp]) == 0:
            print('none of ' + cmp + ' stock information on earnings call dates are accessible')
            # if there are no more earnings call date for this company, stop iteration
            continue
        
        if remove_count == orig_count:
            continue
                
        for earn_date in earn_dict[cmp]:
            # iterate through the earnings call dates of each companies. Remove last item since it may not have sufficient information
                                    
            datetime_earn_date = datetime.strptime(earn_date, date_format)
            # convert string dates to datetime objects for comparison
            
            while not(datetime_earn_date in yfdata.index):
                #print('datetime not accessible. current datetime: ' + str(datetime_earn_date))
                datetime_earn_date -= timedelta(days = 1) # If the earnings call date is not a market open date, go back a day until it is
                #print('new datetime: ' + str(datetime_earn_date))
            
            key_index = yfdata_index.index(datetime_earn_date) # Get the index number of the earnings call date
            
            factor = yfdata.loc[yfdata_index[key_index]].at['Close'] / yfdata.loc[yfdata_index[key_index]].at['Adj Close']
            
            df_row = {'Day 0': yfdata.loc[yfdata_index[key_index]].at['Adj Close'],
                      'Day +1': yfdata.loc[yfdata_index[key_index+1]].at['Open'] / factor,
                      'Day +2': yfdata.loc[yfdata_index[key_index+2]].at['Open'] / factor,
                      'Day +7': yfdata.loc[yfdata_index[key_index+5]].at['Open'] / factor,
                      'Day +28': yfdata.loc[yfdata_index[key_index+20]].at['Open'] / factor, 
                      'Day +63': yfdata.loc[yfdata_index[key_index+45]].at['Open'] / factor}
            # Get the closing price of the stock before earnings call, and compare with the opening price of
            # four days: the day right after the earnings call, 2 days later, a week later, and a month later
            
            #print(df_row)
            
            price_df.loc[earn_date] = df_row
            
            gap_row = {'Day +1': df_row['Day +1'] - df_row['Day 0'], 
                       'Day +2': df_row['Day +2'] - df_row['Day 0'], 
                       'Day +7': df_row['Day +7'] - df_row['Day 0'], 
                       'Day +28': df_row['Day +28'] - df_row['Day 0'], 
                       'Day +63': df_row['Day +63'] - df_row['Day 0']}
            # From df_row, calculate the gap between closing price of stock before earnings call with four opening prices.
            
            price_gap.loc[earn_date] = gap_row
            
            perc_row = {'Day +1': (df_row['Day +1'] / df_row['Day 0'])*100 -100, 
                       'Day +2': (df_row['Day +2'] / df_row['Day 0'])*100 - 100, 
                       'Day +7': (df_row['Day +7'] / df_row['Day 0'])*100 - 100, 
                       'Day +28': (df_row['Day +28'] / df_row['Day 0'])*100 - 100,
                       'Day +63': (df_row['Day +63'] / df_row['Day 0'])*100 - 100 }
            #From df_row, calculate the percentage change between closing price of stock before earnings call with four opening prices.
            
            price_perc.loc[earn_date] = perc_row
            
        #print(price_df)
        #print(price_gap)
        #print(price_perc)
        if not os.path.exists(currwd + '/statistical_data/' + inds + '/' + cmp + '/' + cmp + 'price_gap.csv'):
            price_gap.to_csv(currwd + '/statistical_data/' + inds + '/' + cmp + '/' + cmp + 'price_gap.csv', sep=',', index=True, encoding='utf-8')
        
        if not os.path.exists(currwd + '/statistical_data/' + inds + '/' + cmp + '/' + cmp + 'price_perc.csv'):
            price_perc.to_csv(currwd + '/statistical_data/' + inds + '/' + cmp + '/' + cmp + 'price_perc.csv', sep=',', index=True, encoding='utf-8')
        
        gap_sum_1 = 0
        gap_sum_2 = 0
        gap_sum_7 = 0
        gap_sum_28 = 0
        gap_sum_63 = 0
        
        for chng in price_gap['Day +1']:
            gap_sum_1 += abs(chng)
        
        for chng in price_gap['Day +2']:
            gap_sum_2 += abs(chng)
            
        for chng in price_gap['Day +7']:
            gap_sum_7 += abs(chng)
        
        for chng in price_gap['Day +28']:
            gap_sum_28 += abs(chng)
            
        for chng in price_gap['Day +63']:
            gap_sum_63 += abs(chng)
            
        gap_avg_row = {'Day +1': gap_sum_1 / len(price_gap['Day +1']), 
                       'Day +2': gap_sum_2 / len(price_gap['Day +1']), 
                       'Day +7': gap_sum_7 / len(price_gap['Day +1']), 
                       'Day +28': gap_sum_28 / len(price_gap['Day +1']), 
                       'Day +63': gap_sum_63 / len(price_gap['Day +1'])}
        #get the average of price gaps(abs value) of each day and save it as a dataframe
        
        #print(cmp, gap_avg_row)
        
        earn_impc_price.loc[cmp] = gap_avg_row
        #print(earn_impc_price)
        
        perc_sum_1 = 0
        perc_sum_2 = 0
        perc_sum_7 = 0
        perc_sum_28 = 0
        perc_sum_63 = 0
        
        for chng in price_perc['Day +1']:
            perc_sum_1 += abs(chng)
        
        for chng in price_perc['Day +2']:
            perc_sum_2 += abs(chng)
            
        for chng in price_perc['Day +7']:
            perc_sum_7 += abs(chng)
        
        for chng in price_perc['Day +28']:
            perc_sum_28 += abs(chng)
        
        for chng in price_perc['Day +63']:
            perc_sum_63 += abs(chng)
            
        perc_avg_row = {'Day +1': perc_sum_1 / len(price_perc['Day +1']), 
                       'Day +2': perc_sum_2 / len(price_perc['Day +1']), 
                       'Day +7': perc_sum_7 / len(price_perc['Day +1']), 
                       'Day +28': perc_sum_28 / len(price_perc['Day +1']), 
                        'Day +63': perc_sum_63 / len(price_perc['Day +1'])}
        #get the average of price percentage change(abs value) of each day and save it as a dataframe
        
        #print(cmp, perc_avg_row)
        earn_impc_perc.loc[cmp] = perc_avg_row
    
    print(inds, earn_impc_perc)
    
    if not os.path.exists(currwd + '/statistical_data/' + inds + '/'+ inds + '_price_gap.csv'):
        earn_impc_price.to_csv(currwd + '/statistical_data/' + inds + '/'+ inds + '_price_gap.csv', sep=',', index=True, encoding='utf-8')
    
    if not os.path.exists(currwd + '/statistical_data/' + inds + '/'+ inds + '_price_perc.csv'):
        earn_impc_perc.to_csv(currwd + '/statistical_data/' + inds + '/' + inds + '_price_perc.csv', sep=',', index=True, encoding='utf-8')
    
    #save the data for each companies to csv file for further analysis
# Out:
# media YY
# [*********************100%%**********************]  1 of 1 completed
# media TGNA
# [*********************100%%**********************]  1 of 1 completed
# media EDR
# [*********************100%%**********************]  1 of 1 completed
# media IAS
# [*********************100%%**********************]  1 of 1 completed
# media CNK
# [*********************100%%**********************]  1 of 1 completed
# media SSTK
# [*********************100%%**********************]  1 of 1 completed
# media SSP
# [*********************100%%**********************]  1 of 1 completed
# media NXST
# [*********************100%%**********************]  1 of 1 completed
# media THRY
# [*********************100%%**********************]  1 of 1 completed
# media SBGI
# [*********************100%%**********************]  1 of 1 completed
# media EVER
# [*********************100%%**********************]  1 of 1 completed
# media MGNI
# [*********************100%%**********************]  1 of 1 completed
# media MYPS
# [*********************100%%**********************]  1 of 1 completed
# media IMAX
# [*********************100%%**********************]  1 of 1 completed
# media DISH
# [*********************100%%**********************]  1 of 1 completed
# media TBLA
# [*********************100%%**********************]  1 of 1 completed
# media PUBM
# [*********************100%%**********************]  1 of 1 completed
# media AMCX
# [*********************100%%**********************]  1 of 1 completed
# media OB
# [*********************100%%**********************]  1 of 1 completed
# media BMBL
# [*********************100%%**********************]  1 of 1 completed
# media EB
# [*********************100%%**********************]  1 of 1 completed
# media WOW
# [*********************100%%**********************]  1 of 1 completed
# media CDLX
# [*********************100%%**********************]  1 of 1 completed
# media VTEX
# [*********************100%%**********************]  1 of 1 completed
# media ATHM
# [*********************100%%**********************]  1 of 1 completed
# media YELP
# [*********************100%%**********************]  1 of 1 completed
# media TRVG
# [*********************100%%**********************]  1 of 1 completed
# media GTN
# [*********************100%%**********************]  1 of 1 completed
# media CABO
# [*********************100%%**********************]  1 of 1 completed
# media NYT
# [*********************100%%**********************]  1 of 1 completed
# media WWE
# media WB
# [*********************100%%**********************]  1 of 1 completed
# media EEX
# [*********************100%%**********************]  1 of 1 completed
# media ATUS
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2017-07-28 00:00:00
# media MAX
# [*********************100%%**********************]  1 of 1 completed
# media STGW
# [*********************100%%**********************]  1 of 1 completed
# media AMC
# [*********************100%%**********************]  1 of 1 completed
# media HUYA
# [*********************100%%**********************]  1 of 1 completed
# media PLTK
# [*********************100%%**********************]  1 of 1 completed
# media ZIP
# [*********************100%%**********************]  1 of 1 completed
# media ZH
# [*********************100%%**********************]  1 of 1 completed
# media IAC
# [*********************100%%**********************]  1 of 1 completed
# media ADV
# [*********************100%%**********************]  1 of 1 completed
# media TRIP
# [*********************100%%**********************]  1 of 1 completed
# media MOMO
# [*********************100%%**********************]  1 of 1 completed
# media CARG
# [*********************100%%**********************]  1 of 1 completed
# media BZ
# [*********************100%%**********************]  1 of 1 completed
# media BILI
# [*********************100%%**********************]  1 of 1 completed
# media DOYU
# [*********************100%%**********************]  1 of 1 completed
# media MANU
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2013-02-15 00:00:00
# media CARS
# [*********************100%%**********************]  1 of 1 completed
# media EVC
# [*********************100%%**********************]  1 of 1 completed
# media IHRT
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2019-08-15 00:00:00
# media MTCH
# [*********************100%%**********************]  1 of 1 completed
# media NCMI
# [*********************100%%**********************]  1 of 1 completed
# media SCPL
# [*********************100%%**********************]  1 of 1 completed
# media YALA
# [*********************100%%**********************]  1 of 1 completed
# media CRTO
# [*********************100%%**********************]  1 of 1 completed
# media IQ
# [*********************100%%**********************]  1 of 1 completed
# media PERI
# [*********************100%%**********************]  1 of 1 completed
# media QNST
# [*********************100%%**********************]  1 of 1 completed
# media GCI
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2006-04-12 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2006-07-12 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2006-10-11 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2007-02-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2007-04-19 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2007-07-18 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2007-10-17 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2008-02-01 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2008-04-21 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2008-07-16 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2008-10-24 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-01-30 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-04-17 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-07-15 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-02-01 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-04-16 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-07-16 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-01-31 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-04-18 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-07-18 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-10-17 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-01-30 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-04-16 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-07-16 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-10-15 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-02-04 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-04-23 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-07-22 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-10-21 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-02-04 00:00:00
# media CCO
# [*********************100%%**********************]  1 of 1 completed
# media SOHU
# [*********************100%%**********************]  1 of 1 completed
# media SCHL
# [*********************100%%**********************]  1 of 1 completed
# media ANGI
# [*********************100%%**********************]  1 of 1 completed
# media MCS
# [*********************100%%**********************]  1 of 1 completed
# media FUBO
# [*********************100%%**********************]  1 of 1 completed
# media TTGT
# [*********************100%%**********************]  1 of 1 completed
# media          Day +1     Day +2     Day +7    Day +28    Day +63
# YY     2.267964   5.447066   6.122717  11.879120  17.857091
# TGNA   0.887801   1.912113   3.073897   6.951523   9.706826
# EDR    4.979619   4.708272   4.998537   9.403532  14.686794
# IAS    3.842628   4.542808  10.580128  15.206241  21.572249
# CNK    0.488312   1.976606   3.270291   8.603505   9.112599
# ...         ...        ...        ...        ...        ...
# SCHL   1.065793   3.352571   4.925757   7.504951  10.268982
# ANGI   2.215040   4.970035   7.256343  15.213190  13.811568
# MCS    0.897855   2.377276   3.622312   9.223145  10.193433
# FUBO  15.722992  15.904701  22.548643  29.917134  40.089635
# TTGT   2.507950   4.435086   5.041748   9.779031  12.072084
#
# [68 rows x 5 columns]

# %% [markdown]
# With the given data, we would further analyze the impact of earnings call on each industries

# %%
inds_perc_stat = pd.DataFrame(columns = ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'])

for inds in data:
        
    inds_gap = pd.DataFrame(columns = ['Day +1', 'Day +2', 'Day +7', 'Day +28', 'Day +63'])
    inds_perc = pd.DataFrame(columns = ['Day +1', 'Day +2', 'Day +7', 'Day +28', 'Day +63'])
        
    csv_file = 'statistical_data/' + inds + '/' + inds + '_price_gap.csv'
    
    with open(csv_file, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
    
        for row in reader:
            key = row.pop('')
            for a in row:
                row[a] = float(row[a])
            inds_gap.loc[key] = row

    csv_file = 'statistical_data/' + inds + '/' + inds + '_price_perc.csv'
    
    with open(csv_file, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
    
        for row in reader:
            key = row.pop('')
            for a in row:
                row[a] = float(row[a])
            inds_perc.loc[key] = row    
    '''
    for day in inds_perc.columns:
        inds_perc[day].plot(title = inds + ' industry ' + str(day) + ' percentage change', kind = 'box')
        plt.savefig('statistical_data/'+inds+'/' + inds + '_industry_' + str(day) + 'percentage_change.png')
        plt.show()
    '''
    
    inds_perc_stat.loc[inds] = inds_perc['Day +1'].describe()
    print(inds, inds_perc['Day +1'].describe())

if not os.path.exists('industry_percentage_statistics.csv'):
        inds_perc_stat.to_csv('industry_percentage_statistics.csv', sep=',', index=True, encoding='utf-8')
# Out:
# transportation count    47.000000
# mean      1.476276
# std       1.219400
# min       0.352523
# 25%       0.865772
# 50%       1.168311
# 75%       1.551727
# max       7.982455
# Name: Day +1, dtype: float64
# materials count    91.000000
# mean      1.359141
# std       1.243954
# min       0.415899
# 25%       0.796071
# 50%       1.067475
# 75%       1.442623
# max       9.677252
# Name: Day +1, dtype: float64
# consumer-services count    88.000000
# mean      2.092266
# std       2.291527
# min       0.174372
# 25%       0.954865
# 50%       1.487761
# 75%       2.272926
# max      14.449636
# Name: Day +1, dtype: float64
# energy count    50.000000
# mean      1.473526
# std       1.110505
# min       0.257400
# 25%       1.064171
# 50%       1.243148
# 75%       1.526159
# max       8.371554
# Name: Day +1, dtype: float64
# pharmaceuticals-biotech count    78.000000
# mean      1.901177
# std       1.482796
# min       0.442632
# 25%       1.020623
# 50%       1.456225
# 75%       2.226987
# max       8.066041
# Name: Day +1, dtype: float64
# healthcare count    102.000000
# mean       2.654354
# std        3.002894
# min        0.460180
# 25%        0.859419
# 50%        1.614108
# 75%        2.642379
# max       15.103362
# Name: Day +1, dtype: float64
# consumer-retailing count    11.000000
# mean      1.421049
# std       1.241541
# min       0.349327
# 25%       0.657232
# 50%       0.867530
# 75%       1.891160
# max       4.443690
# Name: Day +1, dtype: float64
# real-estate count    108.000000
# mean       0.868688
# std        1.118949
# min        0.246686
# 25%        0.484509
# 50%        0.601454
# 75%        0.835866
# max        8.512111
# Name: Day +1, dtype: float64
# capital-goods count    92.000000
# mean      1.529932
# std       2.057121
# min       0.389723
# 25%       0.741000
# 50%       0.918096
# 75%       1.393133
# max      13.173045
# Name: Day +1, dtype: float64
# retail count    76.000000
# mean      2.240978
# std       2.130008
# min       0.471717
# 25%       0.976207
# 50%       1.462880
# 75%       2.406306
# max      10.085085
# Name: Day +1, dtype: float64
# software count    80.000000
# mean      3.851838
# std       4.044539
# min       0.288526
# 25%       1.039779
# 50%       2.390836
# 75%       4.928965
# max      18.847661
# Name: Day +1, dtype: float64
# utilities count    33.000000
# mean      0.684753
# std       0.598116
# min       0.294285
# 25%       0.400692
# 50%       0.502872
# 75%       0.755118
# max       3.626234
# Name: Day +1, dtype: float64
# food-beverage-tobacco count    30.000000
# mean      1.748954
# std       2.484920
# min       0.399445
# 25%       0.687436
# 50%       0.966649
# 75%       1.587779
# max      13.345664
# Name: Day +1, dtype: float64
# telecom count    21.000000
# mean      1.844339
# std       1.445404
# min       0.364092
# 25%       0.960192
# 50%       1.214374
# 75%       2.853777
# max       5.981140
# Name: Day +1, dtype: float64
# automobiles count    23.000000
# mean      1.162688
# std       0.729208
# min       0.436181
# 25%       0.806389
# 50%       0.963745
# 75%       1.151995
# max       3.864870
# Name: Day +1, dtype: float64
# diversified-financials count    74.000000
# mean      1.715133
# std       3.404789
# min       0.220835
# 25%       0.663598
# 50%       0.882094
# 75%       1.457828
# max      26.972454
# Name: Day +1, dtype: float64
# consumer-durables count    72.000000
# mean      2.163698
# std       2.556281
# min       0.450172
# 25%       0.849589
# 50%       1.027836
# 75%       1.888575
# max      13.868194
# Name: Day +1, dtype: float64
# household count    19.000000
# mean      1.931393
# std       1.897371
# min       0.482551
# 25%       0.874446
# 50%       1.246390
# 75%       1.873290
# max       7.605972
# Name: Day +1, dtype: float64
# tech count    76.000000
# mean      1.985356
# std       1.712936
# min       0.505370
# 25%       0.914138
# 50%       1.541936
# 75%       2.285761
# max      11.350426
# Name: Day +1, dtype: float64
# banks count    104.000000
# mean       0.980184
# std        0.546051
# min        0.336588
# 25%        0.746234
# 50%        0.857510
# 75%        1.072589
# max        4.779409
# Name: Day +1, dtype: float64
# insurance count    45.000000
# mean      1.723659
# std       3.758222
# min       0.145400
# 25%       0.537818
# 50%       0.778103
# 75%       1.127436
# max      24.351941
# Name: Day +1, dtype: float64
# semiconductors count    48.000000
# mean      2.459550
# std       2.452836
# min       0.648851
# 25%       1.178058
# 50%       1.721506
# 75%       2.488998
# max      15.217382
# Name: Day +1, dtype: float64
# commercial-services count    63.000000
# mean      1.404846
# std       1.520454
# min       0.403533
# 25%       0.718827
# 50%       0.974075
# 75%       1.507743
# max      11.033142
# Name: Day +1, dtype: float64
# media count    68.000000
# mean      2.647266
# std       2.871509
# min       0.000000
# 25%       0.972005
# 50%       1.461700
# 75%       3.396664
# max      15.722992
# Name: Day +1, dtype: float64

# %%
inds_perc = pd.DataFrame(columns = ['Day +1', 'Day +2', 'Day +7', 'Day +28', 'Day +63'])
csv_file = 'statistical_data/' + 'software' + '/' + 'software' + '_price_perc.csv'

with open(csv_file, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        key = row.pop('')
        for a in row:
            row[a] = float(row[a])
        inds_perc.loc[key] = row

print(inds_perc)
# Out:
#         Day +1     Day +2     Day +7    Day +28    Day +63
# DXC   1.034003   3.382222   5.501011   6.823822   9.384537
# TENB  6.004739   7.682738   9.956450  14.218718  20.348916
# ESMT  2.458208   1.835900   7.676030  11.555466  10.827066
# CCCS  1.293284   4.215415   9.786304   6.757474   8.749839
# GWRE  1.897482   3.364249   4.402241   5.909805   8.692353
# ...        ...        ...        ...        ...        ...
# RNG   3.652802   5.982618   7.743854   9.435275  13.962908
# SQSP  4.782690   7.918694   6.431379  10.530074  21.295527
# APPN  3.996511   5.101206   8.966247  13.801412  18.187289
# MNDY  0.288526  10.819672  29.554103  20.613113  18.796717
# FOUR  0.883429   2.455254   0.757232   1.388250   8.581922
#
# [80 rows x 5 columns]

# %%
plt.hist(inds_perc['Day +1'], bins = 20)
plt.title('Price Percentage Change of Software Industry on Day +1')
plt.xlabel('Percentage Change In Price')
plt.ylabel('Number of Companies')
plt.savefig('statistical_data/software/software_price_perc_Day+1_hist.png')
#plt.show()

# %%
plt.hist(inds_perc['Day +7'], bins = 20)
plt.title('Price Percentage Change of Software Industry on Day +7')
plt.xlabel('Percentage Change In Price')
plt.ylabel('Number of Companies')
plt.savefig('statistical_data/software/software_price_perc_Day+7_hist.png')
#plt.show()

# %%
plt.hist(inds_perc['Day +63'], bins = 20)
plt.title('Price Percentage Change of Software Industry on Day +63')
plt.xlabel('Percentage Change In Price')
plt.ylabel('Number of Companies')
plt.savefig('statistical_data/software/software_price_perc_Day+63_hist.png')
#plt.show()
