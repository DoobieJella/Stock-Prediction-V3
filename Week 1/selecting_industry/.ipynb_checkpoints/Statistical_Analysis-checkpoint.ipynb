# %%
#!pip install yfinance
import yfinance as yf
import pandas as pd
import csv
import glob
import os
import matplotlib.pyplot as plt
import numpy as np
import statistics
from datetime import datetime, timedelta

# %% [markdown]
# open csv file and save it as a dictionary

# %%
csv_file = 'filtered_stock.csv'

data = {}

# Read data from the CSV file
with open(csv_file, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    
    for row in reader:
        key = row['Key']
        values = row['Values'].split(', ')  # Split the values by commas
        data[key] = values
        
# Now 'data' contains the dictionary you originally wrote to the CSV file
print(data.keys())
# Out:
# dict_keys(['transportation', 'materials', 'consumer-services', 'energy', 'pharmaceuticals-biotech', 'healthcare', 'consumer-retailing', 'real-estate', 'capital-goods', 'retail', 'software', 'utilities', 'food-beverage-tobacco', 'telecom', 'automobiles', 'diversified-financials', 'consumer-durables', 'household', 'tech', 'banks', 'insurance', 'semiconductors', 'commercial-services', 'media'])

# %% [markdown]
# Fetch the earning call dates for each companies

# %%
raw_earn_dict = {}

for inds in data:
    file_loc = '../sectors/' + inds 
    
    for cmp in data[inds]:
        folder_names = glob.glob(file_loc + '/' + cmp + '/*') #folder_names contain name of all earnings call files of the selected company
        
        for name in folder_names:
            if 'names' in name:
                folder_names.remove(name) #remove the file with presentor names
                
        raw_earn_dates = []
        
        for earn_logs in folder_names:
            file = open(earn_logs, encoding='utf8') #added encoding = 'utf8' because my OS is in Korean
            earn_log = csv.reader(file)
            next(earn_log)
            next(earn_log)
            earn_date = next(earn_log) #get the earnings call date and time            
            raw_earn_dates.append(earn_date)
            
        if(len(folder_names) != len(raw_earn_dates)):
            print('error')
            
        raw_earn_dict[cmp] = raw_earn_dates #append earn-dates to dictionary earn_dict with key being the company name and element being earnings call dates

raw_earn_dict['SCHN.SW'] = raw_earn_dict.pop('SCHN')

print(raw_earn_dict.keys(), len(raw_earn_dict.keys()))
# Out:
# dict_keys(['SB', 'ULCC', 'PANL', 'AAL', 'RLGT', 'GNK', 'CAR', 'ARCB', 'CPA', 'DSKE', 'FWRD', 'WERN', 'TSP', 'SBLK', 'XPO', 'LYFT', 'SNCY', 'ULH', 'SKYW', 'JOBY', 'R', 'GOGL', 'ALK', 'KEX', 'ALGT', 'CHRW', 'LSTR', 'ZIM', 'NETI', 'KNX', 'UP', 'GSL', 'CMRE', 'HA', 'SNDR', 'YMM', 'HUBG', 'EGLE', 'DAC', 'GXO', 'SAVE', 'UHAL', 'MATX', 'JBLU', 'ATSG', 'DSX', 'CAAP', 'CVLG', 'CDE', 'AMR', 'CMC', 'PCT', 'LXU', 'DRD', 'CMP', 'CBT', 'EMN', 'AXTA', 'BERY', 'TROX', 'NEXA', 'HAYN', 'BIOX', 'SMG', 'HL', 'MUX', 'NEU', 'IPI', 'TRS', 'SLGN', 'PTVE', 'RYI', 'KRO', 'TSE', 'SEE', 'VVV', 'SXT', 'CCK', 'PACK', 'CLF', 'GEF', 'BVN', 'LPX', 'MERC', 'HUN', 'CENX', 'OEC', 'BCPC', 'KOP', 'TX', 'MTRN', 'ECVT', 'IOSP', 'LOMA', 'KALU', 'CSTM', 'SUM', 'SLVM', 'AMBP', 'AVD', 'MYE', 'MP', 'GSM', 'ASPN', 'HCC', 'AA', 'GPK', 'ESI', 'TMST', 'ASH', 'RGLD', 'SCL', 'ATR', 'CC', 'CRS', 'ATI', 'KWR', 'FF', 'FMC', 'DNA', 'WOR', 'AVNT', 'EXP', 'OI', 'MTX', 'OLN', 'CLW', 'NGVT', 'MATV', 'X', 'LTHM', 'SXC', 'ZEUS', 'WRK', 'ASIX', 'FUL', 'TMC', 'METC', 'DENN', 'LRN', 'ADT', 'CHUY', 'CHH', 'PTLO', 'AGS', 'GHG', 'DESP', 'OSW', 'ARCE', 'NCLH', 'SHAK', 'NRDY', 'TAST', 'CZR', 'FRGI', 'RICK', 'TXRH', 'RSI', 'PZZA', 'BJRI', 'SCI', 'INSE', 'ARMK', 'MTN', 'STRA', 'DAO', 'BYD', 'VTRU', 'PRDO', 'ROVR', 'EWCZ', 'PLYA', 'MCW', 'TAL', 'UTI', 'WW', 'CBRL', 'LIND', 'MMYT', 'LINC', 'PENN', 'HRB', 'BFAM', 'EAT', 'MLCO', 'IGT', 'EVRI', 'BLMN', 'LAUR', 'DIN', 'CSV', 'KRUS', 'ARCO', 'BALY', 'CHDN', 'LOPE', 'FTDR', 'JACK', 'RRR', 'CHGG', 'VSTA', 'AFYA', 'NGMS', 'ATGE', 'HGV', 'NAAS', 'DUOL', 'WEN', 'SIX', 'ACEL', 'PLAY', 'BROS', 'COUR', 'GDEN', 'PLNT', 'PBPB', 'GENI', 'LOCO', 'UDMY', 'TH', 'WING', 'VAC', 'CAKE', 'SEAS', 'TNL', 'DNUT', 'WH', 'MGY', 'STNG', 'PTEN', 'CNX', 'ETRN', 'RES', 'SM', 'CEIX', 'FRO', 'EVA', 'CLNE', 'HP', 'AM', 'XPRO', 'NOG', 'WHD', 'RRC', 'DEN', 'REGI', 'GPRE', 'CRK', 'ESTE', 'INSW', 'NBR', 'CRC', 'GPOR', 'HPK', 'CHRD', 'TALO', 'CHX', 'BTU', 'RIG', 'ENLC', 'FTI', 'LBRT', 'DTM', 'MUR', 'CVI', 'ARCH', 'GLNG', 'AR', 'CPE', 'NFE', 'NE', 'NOV', 'HESM', 'NEX', 'DK', 'MTDR', 'RTLR', 'PBF', 'KOS', 'SWN', 'WFRD', 'MRTX', 'TLRY', 'IRWD', 'ARWR', 'AMPH', 'TWST', 'OGN', 'SRPT', 'TVTX', 'BIO', 'BPMC', 'SNDX', 'IMGN', 'SHC', 'RVMD', 'CERE', 'TXG', 'RGEN', 'NEO', 'CLDX', 'RYTM', 'STVN', 'MEDP', 'RVNC', 'TGTX', 'SYNH', 'BHC', 'CRL', 'INSM', 'CPRX', 'ADPT', 'PACB', 'MRVI', 'HALO', 'CTLT', 'SUPN', 'NTRA', 'PRGO', 'VCYT', 'XENE', 'FATE', 'ABCL', 'CTKB', 'CYTK', 'MYGN', 'LGND', 'BCRX', 'IOVA', 'ZLAB', 'PTCT', 'RETA', 'RARE', 'ASND', 'ALLO', 'EXEL', 'NVAX', 'APLS', 'IONS', 'CORT', 'ACAD', 'ITCI', 'TEVA', 'XNCR', 'BRKR', 'FOLD', 'BEAM', 'QGEN', 'NTLA', 'AGIO', 'PCRX', 'TECH', 'DVAX', 'ACRS', 'AXSM', 'HRMY', 'ELAN', 'ALKS', 'PBH', 'SAGE', 'JAZZ', 'NVST', 'ICUI', 'AMN', 'AHCO', 'NRC', 'PODD', 'PRCT', 'TFX', 'MASI', 'OMCL', 'OMI', 'GKOS', 'RCM', 'HIMS', 'QDEL', 'IRTC', 'EHC', 'NARI', 'GMED', 'CCRN', 'GH', 'EVH', 'TDOC', 'UHS', 'MODV', 'USPH', 'LIVN', 'SGRY', 'DH', 'ATEC', 'PDCO', 'MPLN', 'OPK', 'ENSG', 'FIGS', 'HAE', 'AMEH', 'SEM', 'SLP', 'SWAV', 'ACCD', 'AXNX', 'OM', 'INSP', 'PRVA', 'BKD', 'SHCR', 'HSIC', 'SENS', 'OPCH', 'ALHC', 'DOCS', 'LFST', 'TMCI', 'THC', 'AGTI', 'PEN', 'RDNT', 'SILK', 'ATRC', 'CSTL', 'LMAT', 'PGNY', 'LNTH', 'PINC', 'HQY', 'STAA', 'MMSI', 'FLGT', 'CHE', 'AGL', 'TMDX', 'MDRX', 'ME', 'CNMD', 'CERT', 'NXGN', 'CERS', 'ACHC', 'CRVL', 'MD', 'NEOG', 'SDGR', 'NUVA', 'VREX', 'ESTA', 'ITGR', 'CLOV', 'NVCR', 'AVNS', 'ADUS', 'TNDM', 'AMED', 'GDRX', 'KIDS', 'DVA', 'HSTM', 'ANGO', 'INMD', 'IART', 'INNV', 'XRAY', 'AMWL', 'NNOX', 'NVRO', 'GO', 'BJ', 'CHEF', 'SFM', 'PFGC', 'ANDE', 'NGVC', 'UNFI', 'PSMT', 'SPTN', 'USFD', 'LAND', 'PCH', 'SAFE', 'BRT', 'ALEX', 'PK', 'FRT', 'LTC', 'NMRK', 'GNL', 'EPRT', 'DBRG', 'UNIT', 'REXR', 'PEB', 'APLE', 'CPT', 'CSR', 'DEA', 'OUT', 'DEI', 'KW', 'RYN', 'RPT', 'CTRE', 'NHI', 'CUBE', 'KRG', 'BDN', 'ESRT', 'HPP', 'OFC', 'EXPI', 'NSA', 'SBRA', 'XHR', 'COMP', 'RDFN', 'AIRC', 'ALX', 'STAG', 'ZG', 'SVC', 'BXP', 'MAC', 'IIPR', 'EGP', 'AAT', 'NTST', 'LXP', 'INN', 'FRPH' ...

# %% [markdown]
# Modify the date to accommodate the time

# %%
date_format_full = '%Y-%m-%d %H:%M:%S'
count = 0
earn_dict = {}

for inds in data:
    
    for cmp in data[inds]:
        earn_dates = []
        if cmp == 'SCHN':
            cmp = 'SCHN.SW'
        for earn_date in raw_earn_dict[cmp]:
            datetime_earn_date = datetime.strptime(earn_date[0], date_format_full)
            datetime_earn_open = datetime_earn_date.replace(hour = 9, minute = 30)
            datetime_earn_close = datetime_earn_date.replace(hour = 16, minute = 0)
            
            if datetime_earn_open < datetime_earn_date and datetime_earn_date < datetime_earn_close:
                #print(cmp + ' in industry ' + inds + ', earnings call happened during marekt time. date: ' + str(datetime_earn_date))
                count += 1 # check if earnings call was happened during market time
                
            elif datetime_earn_date < datetime_earn_open:
                datetime_earn_date -= timedelta(days=1)
                #print('change to date, new date is :' + str(datetime_earn_date))
                # check if earnings call was happened before market open time
                
                earn_dates.append(str(datetime_earn_date.date())) #append the dates to earn_dates
            
            else:
                earn_dates.append(str(datetime_earn_date.date())) #append the dates to earn_dates
            
        if(len(earn_dates) != 0):
            earn_dict[cmp] = earn_dates

for cmp in earn_dict.keys():
    print(cmp, len(earn_dict[cmp]))
# Out:
# SB 29
# ULCC 5
# PANL 21
# AAL 26
# RLGT 29
# GNK 29
# CAR 50
# ARCB 35
# CPA 41
# DSKE 15
# FWRD 35
# WERN 12
# TSP 5
# SBLK 49
# XPO 33
# LYFT 15
# SNCY 6
# ULH 15
# SKYW 39
# JOBY 5
# R 52
# GOGL 16
# ALK 41
# KEX 37
# ALGT 39
# CHRW 54
# LSTR 46
# ZIM 2
# NETI 1
# KNX 17
# UP 5
# GSL 32
# CMRE 27
# HA 39
# SNDR 18
# YMM 1
# HUBG 35
# EGLE 18
# DAC 29
# SAVE 32
# UHAL 32
# MATX 40
# JBLU 54
# ATSG 35
# DSX 48
# CAAP 7
# CVLG 4
# CDE 54
# AMR 4
# CMC 48
# PCT 4
# LXU 35
# DRD 5
# CMP 41
# CBT 40
# EMN 47
# AXTA 24
# BERY 38
# TROX 33
# NEXA 2
# HAYN 28
# BIOX 4
# SMG 40
# HL 53
# MUX 25
# NEU 38
# IPI 50
# TRS 37
# SLGN 42
# PTVE 1
# RYI 25
# KRO 5
# TSE 25
# SEE 55
# VVV 17
# SXT 32
# CCK 44
# PACK 3
# CLF 48
# GEF 39
# BVN 25
# SCHN.SW 41
# LPX 55
# MERC 37
# HUN 54
# CENX 58
# OEC 23
# BCPC 40
# KOP 35
# TX 26
# MTRN 35
# ECVT 5
# IOSP 32
# LOMA 7
# KALU 40
# CSTM 29
# SUM 20
# SLVM 3
# AMBP 3
# AVD 38
# MYE 29
# MP 8
# GSM 31
# ASPN 29
# HCC 36
# AA 60
# GPK 53
# ESI 17
# TMST 21
# ASH 40
# RGLD 39
# SCL 33
# ATR 40
# CC 18
# CRS 52
# ATI 51
# KWR 32
# FF 12
# FMC 46
# DNA 5
# WOR 35
# AVNT 2
# EXP 32
# OI 45
# MTX 37
# OLN 53
# CLW 36
# NGVT 19
# MATV 31
# X 46
# LTHM 15
# SXC 29
# ZEUS 51
# WRK 36
# ASIX 13
# FUL 33
# TMC 5
# METC 13
# DENN 44
# LRN 38
# ADT 20
# CHUY 34
# CHH 41
# PTLO 2
# AGS 16
# GHG 12
# DESP 10
# OSW 3
# ARCE 13
# NCLH 30
# SHAK 26
# NRDY 5
# TAST 51
# CZR 40
# FRGI 37
# RICK 38
# TXRH 40
# RSI 7
# PZZA 32
# BJRI 40
# SCI 47
# INSE 4
# ARMK 24
# MTN 38
# STRA 41
# DAO 5
# BYD 58
# VTRU 8
# PRDO 45
# ROVR 5
# EWCZ 4
# PLYA 12
# MCW 3
# TAL 24
# UTI 35
# MATW 31
# TBI 37
# YY 37
# TGNA 21
# EDR 7
# IAS 4
# CNK 32
# SSTK 31
# SSP 35
# NXST 50
# THRY 4
# SBGI 32
# EVER 19
# MGNI 8
# MYPS 5
# IMAX 43
# DISH 53
# TBLA 1
# PUBM 8
# AMCX 28
# OB 1
# BMBL 7
# EB 14
# WOW 11
# CDLX 17
# VTEX 4
# ATHM 27
# YELP 42
# TRVG 13
# GTN 49
# CABO 21
# NYT 57
# WWE 56
# WB 24
# EEX 15
# ATUS 18
# MAX 8
# STGW 1
# AMC 32
# HUYA 7
# PLTK 4
# ZIP 6
# ZH 2
# IAC 43
# ADV 6
# TRIP 27
# MOMO 22
# CARG 17
# BZ 1
# BILI 10
# DOYU 4
# MANU 30
# CARS 15
# EVC 36
# IHRT 10
# MTCH 12
# NCMI 38
# SCPL 5
# YALA 5
# CRTO 24
# IQ 10
# PERI 46
# QNST 35
# GCI 57
# CCO 33
# SOHU 60
# SCHL 57
# ANGI 23
# MCS 45
# FUBO 7
# TTGT 37

# %% [markdown]
# Check if there are no null values

# %%
for cmp in earn_dict.keys():
    if(len(earn_dict[cmp]) == 0):
        print(cmp, earn_dict[cmp])

# %%
print('total count of earnings call during market time: ' + str(count))
# Out:
# total count of earnings call during market time: 5264

# %% [markdown]
# Write the earning call date dictionary as csv file

# %%
csv_file = 'earning_call_dates.csv'

with open(csv_file, 'w', newline='') as csvfile:
    fieldnames = ['Key', 'Values']  # Define the CSV header
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    # Write the header row
    writer.writeheader()
    
    # Write data from the dictionary to the CSV
    for key, values in earn_dict.items():
        writer.writerow({'Key': key, 'Values': ', '.join(values)})

# %% [markdown]
# Open the earnings call date dictionary file

# %%
csv_file = 'earning_call_dates.csv'

earn_dict = {}

# Read data from the CSV file
with open(csv_file, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    
    for row in reader:
        key = row['Key']
        values = row['Values'].split(', ')  # Split the values by commas
        earn_dict[key] = values

# Now 'data' contains the dictionary you originally wrote to the CSV file

# %% [markdown]
# Create folders for each industires

# %%
if not os.path.exists('statistical_data'):
    os.mkdir('statistical_data')

for inds in data:
    if not os.path.exists('statistical_data/' + inds):
        os.mkdir('statistical_data/' + inds)
        
    for cmp in data[inds]:
        if cmp == 'SCHN':
            cmp = 'SCHN.SW'
        if not(cmp in earn_dict.keys()):
            continue
        if not os.path.exists('statistical_data/' + inds + '/' + cmp):
            os.mkdir('statistical_data/' + inds + '/' + cmp)

if not os.path.exists('new_statistical_data'):
    os.mkdir('new_statistical_data')

for inds in data:
    if not os.path.exists('new_statistical_data/' + inds):
        os.mkdir('new_statistical_data/' + inds)
        
    for cmp in data[inds]:
        if cmp == 'SCHN':
            cmp = 'SCHN.SW'
        if not(cmp in earn_dict.keys()):
            continue
        if not os.path.exists('new_statistical_data/' + inds + '/' + cmp):
            os.mkdir('new_statistical_data/' + inds + '/' + cmp)

# %% [markdown]
# Create a dataframe for each company with stock prices for various dates

# %%
date_format = '%Y-%m-%d'
currwd = os.getcwd()

csv_file = 'earning_call_dates.csv'

earn_dict = {}

# Read data from the CSV file
with open(csv_file, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    
    for row in reader:
        key = row['Key']
        values = row['Values'].split(', ')  # Split the values by commas
        earn_dict[key] = values

# Now 'data' contains the dictionary you originally wrote to the CSV file

for inds in data:
    
    earn_impc_price = pd.DataFrame(columns = ['Day +1', 'Day +2', 'Day +7', 'Day +14', 'Day +28', 'Day +63'])
    earn_impc_perc = pd.DataFrame(columns = ['Day +1', 'Day +2', 'Day +7', 'Day +14', 'Day +28', 'Day +63'])
    #create two dataframes, one for recording average price gap and the other for recording avearge price percentage change.
    
    for cmp in data[inds]:
            
        print(inds, cmp)
        if cmp == 'SCHN':
            cmp = 'SCHN.SW'
        if not(cmp in earn_dict.keys()):
            continue
        
        price_df = pd.DataFrame(columns=['Day 0', 'Day +1', 'Day +2', 'Day +7', 'Day +14', 'Day +28', 'Day +63'])
        price_gap = pd.DataFrame(columns=['Day +1', 'Day +2', 'Day +7', 'Day +14', 'Day +28', 'Day +63'])
        price_perc = pd.DataFrame(columns=['Day +1', 'Day +2', 'Day +7', 'Day +14', 'Day +28', 'Day +63'])
        #create three dataframes, one for tracking price data, one for tracking price gap, one for tracking price percentage change
        
        if(cmp == 'NEX' or cmp == 'NUVA' or cmp == 'QUOT' or cmp == 'WWE' or cmp == 'FRGI' 
           or cmp == 'DEN' or cmp == 'ESTE' or cmp == 'SYNH' or cmp == 'RETA' or cmp == 'NXGN'
           or cmp == 'OFC' or cmp == 'TRTN' or cmp == 'OSTK' or cmp == 'NEWR' or cmp == 'NCR'
           or cmp == 'TWNK' or cmp == 'RADI'):
            continue
            
        yfdata = yf.download(cmp) 
        yfdata_index = list(yfdata.index) # get the list of dates available from yfdata
        
        datetime_start_date = datetime.strptime(earn_dict[cmp][0], date_format) # mark the starting date from earnings call dates
        
        orig_count = len(earn_dict[cmp])
        remove_count = 0
        while(datetime_start_date < yfdata_index[0]):
            remove_count += 1
            earn_dict[cmp] = earn_dict[cmp][1:]
            # if the earliest earnings call date is before the earliest accessable stock price date, remove that date earnings call date
            
            if len(earn_dict[cmp]) == 0:
                # if there are no more earnings call date for this company, stop iteration
                break
                
            datetime_start_date = datetime.strptime(earn_dict[cmp][0], date_format)
            # get new start date to compare
            
            print('stock price not accessible in this date. Recalibrating start date to: ' + str(datetime_start_date))
            
        if len(earn_dict[cmp]) == 0:
            print('none of ' + cmp + ' stock information on earnings call dates are accessible')
            # if there are no more earnings call date for this company, stop iteration
            continue
        
        if remove_count == orig_count:
            continue
                
        for earn_date in earn_dict[cmp]:
            # iterate through the earnings call dates of each companies. Remove last item since it may not have sufficient information
                                    
            datetime_earn_date = datetime.strptime(earn_date, date_format)
            # convert string dates to datetime objects for comparison
            
            while not(datetime_earn_date in yfdata.index):
                #print('datetime not accessible. current datetime: ' + str(datetime_earn_date))
                datetime_earn_date -= timedelta(days = 1) # If the earnings call date is not a market open date, go back a day until it is
                #print('new datetime: ' + str(datetime_earn_date))
            
            key_index = yfdata_index.index(datetime_earn_date) # Get the index number of the earnings call date
            
            factor = yfdata.loc[yfdata_index[key_index]].at['Close'] / yfdata.loc[yfdata_index[key_index]].at['Adj Close']
            
            df_row = {'Day 0': yfdata.loc[yfdata_index[key_index]].at['Adj Close'],
                      'Day +1': yfdata.loc[yfdata_index[key_index+1]].at['Open'] / factor,
                      'Day +2': yfdata.loc[yfdata_index[key_index+2]].at['Open'] / factor,
                      'Day +7': yfdata.loc[yfdata_index[key_index+5]].at['Open'] / factor,
                      'Day +14': yfdata.loc[yfdata_index[key_index+10]].at['Open'] / factor,
                      'Day +28': yfdata.loc[yfdata_index[key_index+20]].at['Open'] / factor, 
                      'Day +63': yfdata.loc[yfdata_index[key_index+45]].at['Open'] / factor}
            # Get the closing price of the stock before earnings call, and compare with the opening price of
            # four days: the day right after the earnings call, 2 days later, a week later, and a month later
            
            #print(df_row)
            
            price_df.loc[earn_date] = df_row
            
            gap_row = {'Day +1': df_row['Day +1'] - df_row['Day 0'], 
                       'Day +2': df_row['Day +2'] - df_row['Day 0'], 
                       'Day +7': df_row['Day +7'] - df_row['Day 0'], 
                       'Day +14': df_row['Day +14'] - df_row['Day 0'],
                       'Day +28': df_row['Day +28'] - df_row['Day 0'], 
                       'Day +63': df_row['Day +63'] - df_row['Day 0']}
            # From df_row, calculate the gap between closing price of stock before earnings call with four opening prices.
            
            price_gap.loc[earn_date] = gap_row
            
            perc_row = {'Day +1': (df_row['Day +1'] / df_row['Day 0'])*100 -100, 
                        'Day +2': (df_row['Day +2'] / df_row['Day 0'])*100 - 100, 
                        'Day +7': (df_row['Day +7'] / df_row['Day 0'])*100 - 100, 
                        'Day +14': (df_row['Day +14'] / df_row['Day 0'])*100 - 100,
                        'Day +28': (df_row['Day +28'] / df_row['Day 0'])*100 - 100,
                        'Day +63': (df_row['Day +63'] / df_row['Day 0'])*100 - 100 }
            #From df_row, calculate the percentage change between closing price of stock before earnings call with four opening prices.
            
            price_perc.loc[earn_date] = perc_row
            
        #print(price_df)
        #print(price_gap)
        #print(price_perc)
        if not os.path.exists(currwd + '/new_statistical_data/' + inds + '/' + cmp + '/' + cmp + 'price_gap.csv'):
            price_gap.to_csv(currwd + '/new_statistical_data/' + inds + '/' + cmp + '/' + cmp + 'price_gap.csv', sep=',', index=True, encoding='utf-8')
        
        if not os.path.exists(currwd + '/new_statistical_data/' + inds + '/' + cmp + '/' + cmp + 'price_perc.csv'):
            price_perc.to_csv(currwd + '/new_statistical_data/' + inds + '/' + cmp + '/' + cmp + 'price_perc.csv', sep=',', index=True, encoding='utf-8')
        
        gap_sum_1 = 0
        gap_sum_2 = 0
        gap_sum_7 = 0
        gap_sum_14 = 0
        gap_sum_28 = 0
        gap_sum_63 = 0
        
        for chng in price_gap['Day +1']:
            gap_sum_1 += chng
        
        for chng in price_gap['Day +2']:
            gap_sum_2 += chng
            
        for chng in price_gap['Day +7']:
            gap_sum_7 += chng
        
        for chng in price_gap['Day +14']:
            gap_sum_14 += chng
        
        for chng in price_gap['Day +28']:
            gap_sum_28 += chng
            
        for chng in price_gap['Day +63']:
            gap_sum_63 += chng
            
        gap_avg_row = {'Day +1': gap_sum_1 / len(price_gap['Day +1']), 
                       'Day +2': gap_sum_2 / len(price_gap['Day +1']), 
                       'Day +7': gap_sum_7 / len(price_gap['Day +1']), 
                       'Day +14': gap_sum_14 / len(price_gap['Day +1']), 
                       'Day +28': gap_sum_28 / len(price_gap['Day +1']), 
                       'Day +63': gap_sum_63 / len(price_gap['Day +1'])}
        #get the average of price gaps of each day and save it as a dataframe
        
        #print(cmp, gap_avg_row)
        
        earn_impc_price.loc[cmp] = gap_avg_row
        #print(earn_impc_price)
        
        perc_sum_1 = 0
        perc_sum_2 = 0
        perc_sum_7 = 0
        perc_sum_14 = 0
        perc_sum_28 = 0
        perc_sum_63 = 0
        
        for chng in price_perc['Day +1']:
            perc_sum_1 += chng
        
        for chng in price_perc['Day +2']:
            perc_sum_2 += chng
            
        for chng in price_perc['Day +7']:
            perc_sum_7 += chng
            
        for chng in price_perc['Day +14']:
            perc_sum_14 += chng
        
        for chng in price_perc['Day +28']:
            perc_sum_28 += chng
        
        for chng in price_perc['Day +63']:
            perc_sum_63 += chng
            
        perc_avg_row = {'Day +1': perc_sum_1 / len(price_perc['Day +1']), 
                        'Day +2': perc_sum_2 / len(price_perc['Day +1']), 
                        'Day +7': perc_sum_7 / len(price_perc['Day +1']), 
                        'Day +14': perc_sum_14 / len(price_perc['Day +1']), 
                        'Day +28': perc_sum_28 / len(price_perc['Day +1']), 
                        'Day +63': perc_sum_63 / len(price_perc['Day +1'])}
        #get the average of price percentage change(abs value) of each day and save it as a dataframe
        
        #print(cmp, perc_avg_row)
        earn_impc_perc.loc[cmp] = perc_avg_row
    
    print(inds, earn_impc_perc)
    
    if not os.path.exists(currwd + '/new_statistical_data/' + inds + '/'+ inds + '_price_gap.csv'):
        earn_impc_price.to_csv(currwd + '/new_statistical_data/' + inds + '/'+ inds + '_price_gap.csv', sep=',', index=True, encoding='utf-8')
    
    if not os.path.exists(currwd + '/new_statistical_data/' + inds + '/'+ inds + '_price_perc.csv'):
        earn_impc_perc.to_csv(currwd + '/new_statistical_data/' + inds + '/' + inds + '_price_perc.csv', sep=',', index=True, encoding='utf-8')
    
    #save the data for each companies to csv file for further analysis
# Out:
# transportation SB
# [*********************100%%**********************]  1 of 1 completed
# transportation ULCC
# [*********************100%%**********************]  1 of 1 completed
# transportation PANL
# [*********************100%%**********************]  1 of 1 completed
# transportation AAL
# [*********************100%%**********************]  1 of 1 completed
# transportation RLGT
# [*********************100%%**********************]  1 of 1 completed
# transportation GNK
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2008-05-16 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2008-07-31 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-03-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-05-04 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-11-07 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-08-05 00:00:00
# transportation CAR
# [*********************100%%**********************]  1 of 1 completed
# transportation ARCB
# [*********************100%%**********************]  1 of 1 completed
# transportation CPA
# [*********************100%%**********************]  1 of 1 completed
# transportation DSKE
# [*********************100%%**********************]  1 of 1 completed
# transportation FWRD
# [*********************100%%**********************]  1 of 1 completed
# transportation WERN
# [*********************100%%**********************]  1 of 1 completed
# transportation TSP
# [*********************100%%**********************]  1 of 1 completed
# transportation SBLK
# [*********************100%%**********************]  1 of 1 completed
# transportation XPO
# [*********************100%%**********************]  1 of 1 completed
# transportation LYFT
# [*********************100%%**********************]  1 of 1 completed
# transportation SNCY
# [*********************100%%**********************]  1 of 1 completed
# transportation ULH
# [*********************100%%**********************]  1 of 1 completed
# transportation SKYW
# [*********************100%%**********************]  1 of 1 completed
# transportation JOBY
# [*********************100%%**********************]  1 of 1 completed
# transportation R
# [*********************100%%**********************]  1 of 1 completed
# transportation GOGL
# [*********************100%%**********************]  1 of 1 completed
# transportation ALK
# [*********************100%%**********************]  1 of 1 completed
# transportation KEX
# [*********************100%%**********************]  1 of 1 completed
# transportation ALGT
# [*********************100%%**********************]  1 of 1 completed
# transportation CHRW
# [*********************100%%**********************]  1 of 1 completed
# transportation LSTR
# [*********************100%%**********************]  1 of 1 completed
# transportation ZIM
# [*********************100%%**********************]  1 of 1 completed
# transportation NETI
# [*********************100%%**********************]  1 of 1 completed
# transportation KNX
# [*********************100%%**********************]  1 of 1 completed
# transportation UP
# [*********************100%%**********************]  1 of 1 completed
# transportation GSL
# [*********************100%%**********************]  1 of 1 completed
# transportation CMRE
# [*********************100%%**********************]  1 of 1 completed
# transportation HA
# [*********************100%%**********************]  1 of 1 completed
# transportation SNDR
# [*********************100%%**********************]  1 of 1 completed
# transportation YMM
# [*********************100%%**********************]  1 of 1 completed
# transportation HUBG
# [*********************100%%**********************]  1 of 1 completed
# transportation EGLE
# [*********************100%%**********************]  1 of 1 completed
# transportation DAC
# [*********************100%%**********************]  1 of 1 completed
# transportation GXO
# transportation SAVE
# [*********************100%%**********************]  1 of 1 completed
# transportation UHAL
# [*********************100%%**********************]  1 of 1 completed
# transportation MATX
# [*********************100%%**********************]  1 of 1 completed
# transportation JBLU
# [*********************100%%**********************]  1 of 1 completed
# transportation ATSG
# [*********************100%%**********************]  1 of 1 completed
# transportation DSX
# [*********************100%%**********************]  1 of 1 completed
# transportation CAAP
# [*********************100%%**********************]  1 of 1 completed
# transportation CVLG
# [*********************100%%**********************]  1 of 1 completed
# transportation         Day +1    Day +2     Day +7    Day +14    Day +28    Day +63
# SB   -0.090661  0.629164   2.027721  -0.721305  -0.192764   3.843380
# ULCC  0.165993  4.166486   5.940115   2.761976   3.504022  -9.737224
# PANL  0.333848 -0.966812  -0.344162   0.383825  -0.598965  -1.977025
# AAL  -0.194400 -1.424224  -2.633283  -2.310800  -1.810901  -1.975937
# RLGT  1.264502  1.928902   2.324084   4.157491   2.622922   4.247422
# GNK   0.683984 -0.610670  -3.020396  -3.076798  -2.552541  -0.131772
# CAR   0.120545  0.126255  -1.818171  -1.036520   0.310450   3.667563
# ARCB  0.067723  0.434185   1.045908   2.045497   3.527799   2.514632
# [*********************100%%**********************]  1 of 1 completed
# materials LXU
# [*********************100%%**********************]  1 of 1 completed
# materials DRD
# [*********************100%%**********************]  1 of 1 completed
# materials CMP
# [*********************100%%**********************]  1 of 1 completed
# materials CBT
# [*********************100%%**********************]  1 of 1 completed
# materials EMN
# [*********************100%%**********************]  1 of 1 completed
# materials AXTA
# [*********************100%%**********************]  1 of 1 completed
# materials BERY
# [*********************100%%**********************]  1 of 1 completed
# materials TROX
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2008-08-29 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-02-21 00:00:00
# materials NEXA
# [*********************100%%**********************]  1 of 1 completed
# materials HAYN
# [*********************100%%**********************]  1 of 1 completed
# materials BIOX
# [*********************100%%**********************]  1 of 1 completed
# materials SMG
# [*********************100%%**********************]  1 of 1 completed
# materials HL
# [*********************100%%**********************]  1 of 1 completed
# materials MUX
# [*********************100%%**********************]  1 of 1 completed
# materials NEU
# [*********************100%%**********************]  1 of 1 completed
# materials IPI
# [*********************100%%**********************]  1 of 1 completed
# materials TRS
# [*********************100%%**********************]  1 of 1 completed
# materials SLGN
# [*********************100%%**********************]  1 of 1 completed
# materials PTVE
# [*********************100%%**********************]  1 of 1 completed
# materials RYI
# [*********************100%%**********************]  1 of 1 completed
# materials KRO
# [*********************100%%**********************]  1 of 1 completed
# materials TSE
# [*********************100%%**********************]  1 of 1 completed
# materials SEE
# [*********************100%%**********************]  1 of 1 completed
# materials VVV
# [*********************100%%**********************]  1 of 1 completed
# materials SXT
# [*********************100%%**********************]  1 of 1 completed
# materials CCK
# [*********************100%%**********************]  1 of 1 completed
# materials PACK
# [*********************100%%**********************]  1 of 1 completed
# materials CLF
# [*********************100%%**********************]  1 of 1 completed
# materials GEF
# [*********************100%%**********************]  1 of 1 completed
# materials BVN
# [*********************100%%**********************]  1 of 1 completed
# materials SCHN
# [*********************100%%**********************]  1 of 1 completed
# materials LPX
# [*********************100%%**********************]  1 of 1 completed
# materials MERC
# [*********************100%%**********************]  1 of 1 completed
# materials HUN
# [*********************100%%**********************]  1 of 1 completed
# materials CENX
# [*********************100%%**********************]  1 of 1 completed
# materials OEC
# [*********************100%%**********************]  1 of 1 completed
# materials BCPC
# [*********************100%%**********************]  1 of 1 completed
# materials KOP
# [*********************100%%**********************]  1 of 1 completed
# materials TX
# [*********************100%%**********************]  1 of 1 completed
# materials MTRN
# [*********************100%%**********************]  1 of 1 completed
# materials ECVT
# [*********************100%%**********************]  1 of 1 completed
# materials IOSP
# [*********************100%%**********************]  1 of 1 completed
# materials LOMA
# [*********************100%%**********************]  1 of 1 completed
# materials KALU
# [*********************100%%**********************]  1 of 1 completed
# materials CSTM
# [*********************100%%**********************]  1 of 1 completed
# materials SUM
# [*********************100%%**********************]  1 of 1 completed
# materials SLVM
# [*********************100%%**********************]  1 of 1 completed
# materials AMBP
# [*********************100%%**********************]  1 of 1 completed
# materials AVD
# [*********************100%%**********************]  1 of 1 completed
# materials MYE
# [*********************100%%**********************]  1 of 1 completed
# materials MP
# [*********************100%%**********************]  1 of 1 completed
# materials GSM
# [*********************100%%**********************]  1 of 1 completed
# materials ASPN
# [*********************100%%**********************]  1 of 1 completed
# materials HCC
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2008-05-07 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2008-08-06 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2008-11-05 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-02-25 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-05-05 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-08-04 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-11-03 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-08-03 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-11-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-02-22 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-05-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-08-01 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-10-31 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-02-13 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-04-29 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2017-08-05 00:00:00
# materials AA
# [*********************100%%**********************]  1 of 1 completed
# materials GPK
# [*********************100%%**********************]  1 of 1 completed
# materials ESI
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2008-04-25 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2008-07-24 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-01-22 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-04-24 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-07-22 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-01-26 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-07-26 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2016-04-29 00:00:00
# materials TMST
# [*********************100%%**********************]  1 of 1 completed
# materials ASH
# [*********************100%%**********************]  1 of 1 completed
# materials RGLD
# [*********************100%%**********************]  1 of 1 completed
# materials SCL
# [*********************100%%**********************]  1 of 1 completed
# materials ATR
# [*********************100%%**********************]  1 of 1 completed
# materials CC
# [*********************100%%**********************]  1 of 1 completed
# materials CRS
# [*********************100%%**********************]  1 of 1 completed
# materials ATI
# [*********************100%%**********************]  1 of 1 completed
# materials KWR
# [*********************100%%**********************]  1 of 1 completed
# materials FF
# [*********************100%%**********************]  1 of 1 completed
# materials FMC
# [*********************100%%**********************]  1 of 1 completed
# materials DNA
# [*********************100%%**********************]  1 of 1 completed
# materials WOR
# [*********************100%%**********************]  1 of 1 completed
# materials AVNT
# [*********************100%%**********************]  1 of 1 completed
# materials EXP
# [*********************100%%**********************]  1 of 1 completed
# materials OI
# [*********************100%%**********************]  1 of 1 completed
# materials MTX
# [*********************100%%**********************]  1 of 1 completed
# materials OLN
# [*********************100%%**********************]  1 of 1 completed
# materials CLW
# [*********************100%%**********************]  1 of 1 completed
# materials NGVT
# [*********************100%%**********************]  1 of 1 completed
# materials MATV
# [*********************100%%**********************]  1 of 1 completed
# materials X
# [*********************100%%**********************]  1 of 1 completed
# materials LTHM
# [*********************100%%**********************]  1 of 1 completed
# materials SXC
# [*********************100%%**********************]  1 of 1 completed
# materials ZEUS
# [*********************100%%**********************]  1 of 1 completed
# materials WRK
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2009-04-28 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-08-03 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-11-10 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-01-25 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-04-26 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-07-25 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-11-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-01-23 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-04-24 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-07-24 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-11-05 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-01-29 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-04-29 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-11-04 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-04-30 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-08-02 00:00:00
# materials ASIX
# [*********************100%%**********************]  1 of 1 completed
# materials FUL
# [*********************100%%**********************]  1 of 1 completed
# materials TMC
# [*********************100%%**********************]  1 of 1 completed
# materials METC
# [*********************100%%**********************]  1 of 1 completed
# materials         Day +1    Day +2    Day +7    Day +14   Day +28    Day +63
# CDE   0.360336  0.000581  0.027199  -1.146920 -0.955837   2.329588
# AMR  -2.127965 -5.588712 -6.655251  -6.461665  3.798010   9.274361
# CMC  -0.201058 -0.333129 -0.236557  -0.280437  2.416204   2.223830
# PCT  -0.635122  2.392075  9.245548  10.430810  9.741242  -5.110336
# LXU   0.745721  0.633451  2.935810   5.951015  6.150309   3.802839
# ...        ...       ...       ...        ...       ...        ...
# WRK  -0.335036 -0.995936 -1.588983  -1.665572 -1.479062  -3.144973
# ASIX -0.731077 -1.206108 -2.248309  -5.315023 -6.946479  -4.784453
# FUL  -0.553836 -0.735942 -0.185330   0.596418  2.475773   2.796443
# TMC   1.195937 -3.111093  3.196071   0.499910 -6.827151 -21.394641
# METC -0.219198  1.499801 -0.716419   4.161293  4.477018   1.981451
#
# [91 rows x 6 columns]
# consumer-services DENN
# [*********************100%%**********************]  1 of 1 completed
# consumer-services LRN
# [*********************100%%**********************]  1 of 1 completed
# consumer-services ADT
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2013-07-31 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-11-20 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-01-30 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-11-11 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2016-02-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2018-03-15 00:00:00
# consumer-services CHUY
# [*********************100%%**********************]  1 of 1 completed
# consumer-services CHH
# [*********************100%%**********************]  1 of 1 completed
# consumer-services PTLO
# [*********************100%%**********************]  1 of 1 completed
# consumer-services AGS
# [*********************100%%**********************]  1 of 1 completed
# consumer-services GHG
# [*********************100%%**********************]  1 of 1 completed
# consumer-services DESP
# [*********************100%%**********************]  1 of 1 completed
# consumer-services OSW
# [*********************100%%**********************]  1 of 1 completed
# consumer-services ARCE
# [*********************100%%**********************]  1 of 1 completed
# consumer-services NCLH
# [*********************100%%**********************]  1 of 1 completed
# consumer-services SHAK
# [*********************100%%**********************]  1 of 1 completed
# consumer-services NRDY
# [*********************100%%**********************]  1 of 1 completed
# consumer-services TAST
# [*********************100%%**********************]  1 of 1 completed
# consumer-services CZR
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2012-11-01 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-02-26 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-05-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-07-30 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-10-30 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-03-12 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-05-07 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-08-12 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-11-11 00:00:00
# consumer-services FRGI
# consumer-services RICK
# [*********************100%%**********************]  1 of 1 completed
# consumer-services TXRH
# [*********************100%%**********************]  1 of 1 completed
# consumer-services RSI
# [*********************100%%**********************]  1 of 1 completed
# consumer-services PZZA
# [*********************100%%**********************]  1 of 1 completed
# consumer-services BJRI
# [*********************100%%**********************]  1 of 1 completed
# consumer-services SCI
# [*********************100%%**********************]  1 of 1 completed
# consumer-services INSE
# [*********************100%%**********************]  1 of 1 completed
# consumer-services ARMK
# [*********************100%%**********************]  1 of 1 completed
# consumer-services MTN
# [*********************100%%**********************]  1 of 1 completed
# consumer-services STRA
# [*********************100%%**********************]  1 of 1 completed
# consumer-services DAO
# [*********************100%%**********************]  1 of 1 completed
# consumer-services BYD
# [*********************100%%**********************]  1 of 1 completed
# consumer-services VTRU
# [*********************100%%**********************]  1 of 1 completed
# consumer-services PRDO
# [*********************100%%**********************]  1 of 1 completed
# consumer-services ROVR
# [*********************100%%**********************]  1 of 1 completed
# consumer-services EWCZ
# [*********************100%%**********************]  1 of 1 completed
# consumer-services PLYA
# [*********************100%%**********************]  1 of 1 completed
# consumer-services MCW
# [*********************100%%**********************]  1 of 1 completed
# consumer-services TAL
# [*********************100%%**********************]  1 of 1 completed
# consumer-services UTI
# [*********************100%%**********************]  1 of 1 completed
# consumer-services WW
# [*********************100%%**********************]  1 of 1 completed
# consumer-services CBRL
# [*********************100%%**********************]  1 of 1 completed
# consumer-services LIND
# [*********************100%%**********************]  1 of 1 completed
# consumer-services MMYT
# [*********************100%%**********************]  1 of 1 completed
# consumer-services LINC
# [*********************100%%**********************]  1 of 1 completed
# consumer-services PENN
# [*********************100%%**********************]  1 of 1 completed
# consumer-services HRB
# [*********************100%%**********************]  1 of 1 completed
# consumer-services BFAM
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2013-03-14 00:00:00
# consumer-services EAT
# [*********************100%%**********************]  1 of 1 completed
# consumer-services MLCO
# [*********************100%%**********************]  1 of 1 completed
# consumer-services IGT
# [*********************100%%**********************]  1 of 1 completed
# consumer-services EVRI
# [*********************100%%**********************]  1 of 1 completed
# consumer-services BLMN
# [*********************100%%**********************]  1 of 1 completed
# consumer-services LAUR
# [*********************100%%**********************]  1 of 1 completed
# consumer-services DIN
# [*********************100%%**********************]  1 of 1 completed
# consumer-services CSV
# [*********************100%%**********************]  1 of 1 completed
# consumer-services KRUS
# [*********************100%%**********************]  1 of 1 completed
# consumer-services ARCO
# [*********************100%%**********************]  1 of 1 completed
# consumer-services BALY
# [*********************100%%**********************]  1 of 1 completed
# consumer-services CHDN
# [*********************100%%**********************]  1 of 1 completed
# consumer-services LOPE
# [*********************100%%**********************]  1 of 1 completed
# consumer-services FTDR
# [*********************100%%**********************]  1 of 1 completed
# consumer-services JACK
# [*********************100%%**********************]  1 of 1 completed
# consumer-services RRR
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2016-11-08 00:00:00
# consumer-services CHGG
# [*********************100%%**********************]  1 of 1 completed
# consumer-services VSTA
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2021-11-11 00:00:00
# consumer-services AFYA
# [*********************100%%**********************]  1 of 1 completed
# consumer-services NGMS
# [*********************100%%**********************]  1 of 1 completed
# consumer-services ATGE
# [*********************100%%**********************]  1 of 1 completed
# consumer-services HGV
# [*********************100%%**********************]  1 of 1 completed
# consumer-services NAAS
# [*********************100%%**********************]  1 of 1 completed
# consumer-services DUOL
# [*********************100%%**********************]  1 of 1 completed
# consumer-services WEN
# [*********************100%%**********************]  1 of 1 completed
# consumer-services SIX
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2008-03-10 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-05-08 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-08-16 00:00:00
# consumer-services ACEL
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2021-05-11 00:00:00
# consumer-services PLAY
# [*********************100%%**********************]  1 of 1 completed
# consumer-services BROS
# [*********************100%%**********************]  1 of 1 completed
# consumer-services COUR
# [*********************100%%**********************]  1 of 1 completed
# consumer-services GDEN
# [*********************100%%**********************]  1 of 1 completed
# consumer-services PLNT
# [*********************100%%**********************]  1 of 1 completed
# consumer-services PBPB
# [*********************100%%**********************]  1 of 1 completed
# consumer-services GENI
# consumer-services LOCO
# [*********************100%%**********************]  1 of 1 completed
# consumer-services UDMY
# [*********************100%%**********************]  1 of 1 completed
# consumer-services TH
# [*********************100%%**********************]  1 of 1 completed
# consumer-services WING
# [*********************100%%**********************]  1 of 1 completed
# consumer-services VAC
# [*********************100%%**********************]  1 of 1 completed
# consumer-services CAKE
# [*********************100%%**********************]  1 of 1 completed
# consumer-services SEAS
# [*********************100%%**********************]  1 of 1 completed
# consumer-services TNL
# [*********************100%%**********************]  1 of 1 completed
# consumer-services DNUT
# [*********************100%%**********************]  1 of 1 completed
# consumer-services WH
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2018-10-30 00:00:00
# consumer-services         Day +1    Day +2     Day +7    Day +14    Day +28    Day +63
# DENN  0.415756  1.606675   1.715184   1.924705   2.597128   0.696698
# LRN   0.686713  0.095877   1.760051   1.805015  -0.220665   1.542049
# ADT  -1.674116 -2.336283  -4.746023  -5.047580  -3.639816  -4.608309
# CHUY -0.003822  0.232773  -0.939597  -1.544017  -1.127808   2.321354
# CHH  -0.014309  0.125962  -0.090136  -0.327283  -0.284668   1.619024
# ...        ...       ...        ...        ...        ...        ...
# CAKE -0.048420  0.235767   0.107227   0.064670  -0.975670   0.922840
# SEAS  0.082970  0.653894   0.462140   0.565566   2.658970   3.750016
# TNL   0.420256  0.761031  -3.532886  -2.538628  -1.853639 -13.048789
# DNUT  3.790356 -1.970265  16.854391  14.262578  16.622664  15.641642
# WH    0.733278  1.858367   3.118096  -0.344722  -1.362345  -1.385510
#
# [87 rows x 6 columns]
# energy MGY
# [*********************100%%**********************]  1 of 1 completed
# energy STNG
# [*********************100%%**********************]  1 of 1 completed
# energy PTEN
# [*********************100%%**********************]  1 of 1 completed
# energy CNX
# [*********************100%%**********************]  1 of 1 completed
# energy ETRN
# [*********************100%%**********************]  1 of 1 completed
# energy RES
# [*********************100%%**********************]  1 of 1 completed
# energy SM
# [*********************100%%**********************]  1 of 1 completed
# energy CEIX
# [*********************100%%**********************]  1 of 1 completed
# energy FRO
# [*********************100%%**********************]  1 of 1 completed
# energy EVA
# [*********************100%%**********************]  1 of 1 completed
# energy CLNE
# [*********************100%%**********************]  1 of 1 completed
# energy HP
# [*********************100%%**********************]  1 of 1 completed
# energy AM
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2008-04-17 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2008-06-25 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2008-09-26 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2008-12-23 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-04-28 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-06-24 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-09-24 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-12-23 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-04-22 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-06-30 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-09-29 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-12-22 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-06-29 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-07-10 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2016-02-25 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2016-04-28 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2016-08-03 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2016-10-27 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2017-03-01 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2017-05-09 00:00:00
# energy XPRO
# [*********************100%%**********************]  1 of 1 completed
# energy NOG
# [*********************100%%**********************]  1 of 1 completed
# energy WHD
# [*********************100%%**********************]  1 of 1 completed
# energy RRC
# [*********************100%%**********************]  1 of 1 completed
# energy DEN
# energy REGI
# [*********************100%%**********************]  1 of 1 completed
# energy GPRE
# [*********************100%%**********************]  1 of 1 completed
# energy CRK
# [*********************100%%**********************]  1 of 1 completed
# energy ESTE
# energy INSW
# [*********************100%%**********************]  1 of 1 completed
# energy NBR
# [*********************100%%**********************]  1 of 1 completed
# energy CRC
# [*********************100%%**********************]  1 of 1 completed
# energy GPOR
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2008-11-24 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-03-21 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-08-09 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-11-07 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-02-28 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-05-08 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-08-07 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-11-06 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-02-27 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-05-08 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-08-07 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-11-06 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-02-26 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-05-06 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-08-06 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-11-07 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2016-02-18 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2016-05-05 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2016-08-05 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2016-11-03 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2017-02-14 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2017-05-09 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2017-08-10 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2017-11-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2018-02-22 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2018-05-09 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2018-08-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2018-11-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2019-02-28 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2019-05-03 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2019-08-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2019-11-01 00:00:00
# none of GPOR stock information on earnings call dates are accessible
# energy HPK
# [*********************100%%**********************]  1 of 1 completed
# energy CHRD
# [*********************100%%**********************]  1 of 1 completed
# energy TALO
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2008-11-06 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-02-18 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-05-07 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-11-04 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-05-05 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-08-04 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-11-06 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-08-03 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-11-07 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-02-26 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-05-07 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-08-06 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-11-05 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-02-25 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-08-06 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-11-03 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2017-11-05 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2018-08-07 00:00:00
# energy CHX
# [*********************100%%**********************]  1 of 1 completed
# energy BTU
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2008-02-15 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2008-04-22 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2008-08-08 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2008-10-16 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-01-27 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-07-21 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-10-21 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-01-26 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-07-21 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-10-20 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-04-19 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-07-19 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-10-25 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-04-19 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-07-24 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-10-22 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-01-29 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-04-18 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-07-23 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-10-17 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-01-30 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-04-24 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-07-22 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-10-20 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2016-02-11 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2017-05-06 00:00:00
# energy RIG
# [*********************100%%**********************]  1 of 1 completed
# energy ENLC
# [*********************100%%**********************]  1 of 1 completed
# energy FTI
# [*********************100%%**********************]  1 of 1 completed
# energy LBRT
# [*********************100%%**********************]  1 of 1 completed
# energy DTM
# energy MUR
# [*********************100%%**********************]  1 of 1 completed
# energy CVI
# [*********************100%%**********************]  1 of 1 completed
# energy ARCH
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2008-10-27 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-01-30 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2009-10-31 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2010-01-29 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-07-29 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2011-10-28 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-02-11 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-05-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-07-27 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-10-26 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-02-05 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-04-23 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-07-30 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-10-29 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-02-04 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-04-22 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2017-02-08 00:00:00
# energy GLNG
# [*********************100%%**********************]  1 of 1 completed
# energy AR
# [*********************100%%**********************]  1 of 1 completed
# energy CPE
# [*********************100%%**********************]  1 of 1 completed
# energy NFE
# [*********************100%%**********************]  1 of 1 completed
# energy NE
# energy NOV
# [*********************100%%**********************]  1 of 1 completed
# energy HESM
# [*********************100%%**********************]  1 of 1 completed
# energy NEX
# energy DK
# GLNG -0.222773  0.042609  0.261868  -2.164269  -0.000602  -2.619667
# ...
# diversified-financials LU
# [*********************100%%**********************]  1 of 1 completed
# diversified-financials NNI
# [*********************100%%**********************]  1 of 1 completed
# diversified-financials GDOT
# [*********************100%%**********************]  1 of 1 completed
# diversified-financials ENVA
# [*********************100%%**********************]  1 of 1 completed
# diversified-financials SNEX
# [*********************100%%**********************]  1 of 1 completed
# diversified-financials FHI
# [*********************100%%**********************]  1 of 1 completed
# diversified-financials LAZ
# [*********************100%%**********************]  1 of 1 completed
# diversified-financials NOAH
# [*********************100%%**********************]  1 of 1 completed
# diversified-financials MAIN
# [*********************100%%**********************]  1 of 1 completed
# diversified-financials RC
# [*********************100%%**********************]  1 of 1 completed
# diversified-financials PRAA
# [*********************100%%**********************]  1 of 1 completed
# diversified-financials VOYA
# [*********************100%%**********************]  1 of 1 completed
# diversified-financials MKTX
# [*********************100%%**********************]  1 of 1 completed
# diversified-financials CODI
# [*********************100%%**********************]  1 of 1 completed
# diversified-financials         Day +1    Day +2    Day +7   Day +14   Day +28   Day +63
# VCTR  0.450592  0.162241  3.723884  4.522930  1.415888  8.406803
# OMF   0.317051  0.373605  1.423884 -1.682031 -0.271788 -2.515718
# ECPG -0.012283 -0.458586 -0.693316 -0.273222 -1.041085 -1.455345
# CACC -0.154179  1.544843  2.619451  3.956235  4.570784  3.762340
# AMG   0.119580  0.524241 -0.686644 -0.412447 -0.432347  0.294971
# ...        ...       ...       ...       ...       ...       ...
# RC    0.341954 -1.196535 -3.593783 -2.073998  2.080417 -0.968593
# PRAA -0.088690  0.422310  0.231922  0.949709  1.032615  3.078814
# VOYA  0.205724 -0.218809  0.729999  1.660477  2.244043  1.504911
# MKTX  0.155042  0.609909  1.090374  0.747648  2.936311  3.745530
# CODI -0.460529 -0.644576  0.172710 -0.206169  0.251035  3.274784
#
# [74 rows x 6 columns]
# consumer-durables MDC
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables MHO
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables TMHC
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables GOLF
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2012-05-15 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2017-05-12 00:00:00
# consumer-durables GRBK
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables SNPO
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables MAT
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables PII
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables PTON
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables HOV
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables SKY
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables SKX
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables LOVE
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables CLAR
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables BC
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables UAA
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables BLD
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2016-05-11 00:00:00
# consumer-durables TPX
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables VUZI
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables VZIO
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables LSEA
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables MTH
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables KTB
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables JAKK
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables PVH
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables ETD
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables CVCO
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables LGIH
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables JOUT
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables CROX
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables CRCT
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables LZB
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables WWW
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables SONO
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables VOXX
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables MHK
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables VFC
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables KBH
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables DTC
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables COLM
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables NWL
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables IBP
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables COOK
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables LEVI
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables SWIM
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables MPX
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables MODG
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables WHR
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables LEG
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables VRA
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables VSTO
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables MCFT
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables HAS
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables OXM
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables IRBT
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables CPRI
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables TPR
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables HBI
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables GPRO
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2007-05-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2007-08-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2007-10-31 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-02-06 00:00:00
# consumer-durables TPH
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables CRI
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables MBUU
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables POWW
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables SHOO
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables SWBI
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables RGR
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables CCS
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables BZH
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables RL
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables HELE
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables YETI
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables MOV
# [*********************100%%**********************]  1 of 1 completed
# consumer-durables         Day +1    Day +2    Day +7   Day +14   Day +28   Day +63
# MDC   0.155182 -0.473916 -1.333142 -1.514097  0.449059 -0.002739
# MHO  -0.148900 -0.043496  0.163376 -0.763386  1.206832 -0.916588
# TMHC -0.020907 -0.431453 -0.859411  1.713851  2.821352  0.952727
# GOLF  0.085804  0.730151  1.013855  1.853670  2.322605  3.647843
# GRBK  0.264834 -0.274338  0.816638  1.307395  2.093137  3.757225
# ...        ...       ...       ...       ...       ...       ...
# BZH   0.473244 -0.879711  0.018460  1.643980  1.984802  1.626247
# RL   -0.197684  0.192724 -0.140762 -1.197031 -0.971933 -1.330661
# HELE  0.038239 -0.916412  0.496789  0.395165  1.420312  2.902375
# YETI -0.527968 -2.553855 -4.562279 -8.485809 -3.514702  3.548869
# MOV  -0.222779 -1.384756 -2.026474 -2.617448 -3.772971 -5.904270
#
# [72 rows x 6 columns]
# household SPB
# [*********************100%%**********************]  1 of 1 completed
# household ENR
# [*********************100%%**********************]  1 of 1 completed
# stock price not accessible in this date. Recalibrating start date to: 2011-11-03 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-02-01 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-05-05 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-08-01 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2012-11-09 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-01-31 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-05-01 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-07-31 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2013-11-05 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-01-29 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-04-30 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-08-02 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2014-11-12 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-01-28 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-05-05 00:00:00
# stock price not accessible in this date. Recalibrating start date to: 2015-08-06 00:00:00
# household SKIN
# [*********************100%%**********************]  1 of 1 completed
# household OLPX
# [*********************100%%**********************]  1 of 1 completed
# household EPC
# [*********************100%%**********************]  1 of 1 completed
# household LFMD
# [*********************100%%**********************]  1 of 1 completed
# household IPAR
# [*********************100%%**********************]  1 of 1 completed
# household NATR
# [*********************100%%**********************]  1 of 1 completed
# household ODC
# [*********************100%%**********************]  1 of 1 completed
# household USNA
# [*********************100%%**********************]  1 of 1 completed
# household HLF
# [*********************100%%**********************]  1 of 1 completed
# household BRBR
# [*********************100%%**********************]  1 of 1 completed
# household COTY
# [*********************100%%**********************]  1 of 1 completed
# household WDFC
# [*********************100%%**********************]  1 of 1 completed
# household REYN
# [*********************100%%**********************]  1 of 1 completed
# household CENT
# [*********************100%%**********************]  1 of 1 completed
# household ELF
# [*********************100%%**********************]  1 of 1 completed
# household NUS
# [*********************100%%**********************]  1 of 1 completed
# household MED
# [*********************100%%**********************]  1 of 1 completed
# household         Day +1    Day +2     Day +7    Day +14    Day +28    Day +63
# SPB   0.168912 -0.261600   0.213779  -0.184276   0.025065   2.981489
# ENR  -0.068719 -0.706292  -0.560966  -0.687180   2.185738   1.188954
# SKIN  3.286555  7.239319  13.976789  11.760915  16.433597  11.002924
# OLPX  0.482551 -1.150710   7.646620  -0.519678   2.338527 -20.564220
# EPC  -0.284347 -0.398237  -0.463701  -0.456310  -0.723418  -3.101998
# LFMD  1.687554  1.872278   4.039814   4.771283   8.246052 -18.548251
# IPAR  0.192765  0.545812   1.343901   1.612132   2.506693   2.502659
# NATR  0.359996 -0.701231   3.369743   2.074359   4.812781   2.166681
# ODC  -0.042717  0.325839   1.878920   1.810538   3.995343   3.608136
# USNA  0.029309 -0.348494   0.319049  -0.338374   0.126442   1.393451
# HLF  -0.456513 -0.578342  -2.124011  -1.970906  -1.746360  -2.201365
# BRBR  1.124333  2.110751   1.019875   3.637605   6.219405   5.735315
# COTY -0.345358 -0.854804   1.167190   1.506491   1.138796  -1.911249
# WDFC  0.227301 -0.515202  -0.092167   0.545949   0.546107   3.131598
# REYN -1.537462 -1.826385  -3.604628  -0.284849   1.806373   6.806190
# CENT  0.357493  0.922608   0.693487  -0.852642  -0.752984   3.996825
# ELF   0.830397  1.876935   1.978145   2.966899   2.226315   3.062274
# NUS  -0.008715  0.375507   0.215790   0.386539   1.485993   3.354617
# MED  -0.077344 -0.542942   1.263617   1.215209   2.689689   5.627826
# tech ROG
# [*********************100%%**********************]  1 of 1 completed
# tech AUDC
# [*********************100%%**********************]  1 of 1 completed
# tech NNDM
# [*********************100%%**********************]  1 of 1 completed
# tech UI
# [*********************100%%**********************]  1 of 1 completed
# tech NSIT
# [*********************100%%**********************]  1 of 1 completed
# tech MASS
# [*********************100%%**********************]  1 of 1 completed
# tech CAN
# [*********************100%%**********************]  1 of 1 completed
# tech EXTR
# [*********************100%%**********************]  1 of 1 completed
# tech ARLO
# [*********************100%%**********************]  1 of 1 completed
# tech IMMR
# [*********************100%%**********************]  1 of 1 completed
# tech AVID
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['AVID']: Exception('%ticker%: No data found, symbol may be delisted')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 51
#      49 orig_count = len(earn_dict[cmp])
#      50 remove_count = 0
# ---> 51 while(datetime_start_date < yfdata_index[0]):
#      52     remove_count += 1
#      53     earn_dict[cmp] = earn_dict[cmp][1:]
#
# IndexError: list index out of range

# %% [markdown]
# With the given data, we would further analyze the impact of earnings call on each industries

# %%
inds_perc_stat = pd.DataFrame(columns = ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'])

for inds in data:
        
    inds_gap = pd.DataFrame(columns = ['Day +1', 'Day +2', 'Day +7', 'Day +28', 'Day +63'])
    inds_perc = pd.DataFrame(columns = ['Day +1', 'Day +2', 'Day +7', 'Day +28', 'Day +63'])
        
    csv_file = 'statistical_data/' + inds + '/' + inds + '_price_gap.csv'
    
    with open(csv_file, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
    
        for row in reader:
            key = row.pop('')
            for a in row:
                row[a] = float(row[a])
            inds_gap.loc[key] = row

    csv_file = 'statistical_data/' + inds + '/' + inds + '_price_perc.csv'
    
    with open(csv_file, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
    
        for row in reader:
            key = row.pop('')
            for a in row:
                row[a] = float(row[a])
            inds_perc.loc[key] = row    
    '''
    for day in inds_perc.columns:
        inds_perc[day].plot(title = inds + ' industry ' + str(day) + ' percentage change', kind = 'box')
        plt.savefig('statistical_data/'+inds+'/' + inds + '_industry_' + str(day) + 'percentage_change.png')
        plt.show()
    '''
    
    inds_perc_stat.loc[inds] = inds_perc['Day +1'].describe()
    print(inds, inds_perc['Day +1'].describe())

if not os.path.exists('industry_percentage_statistics.csv'):
        inds_perc_stat.to_csv('industry_percentage_statistics.csv', sep=',', index=True, encoding='utf-8')
# Out:
# transportation count    47.000000
# mean      1.476276
# std       1.219400
# min       0.352523
# 25%       0.865772
# 50%       1.168311
# 75%       1.551727
# max       7.982455
# Name: Day +1, dtype: float64
# materials count    91.000000
# mean      1.359141
# std       1.243954
# min       0.415899
# 25%       0.796071
# 50%       1.067475
# 75%       1.442623
# max       9.677252
# Name: Day +1, dtype: float64
# consumer-services count    88.000000
# mean      2.092266
# std       2.291527
# min       0.174372
# 25%       0.954865
# 50%       1.487761
# 75%       2.272926
# max      14.449636
# Name: Day +1, dtype: float64
# energy count    50.000000
# mean      1.473526
# std       1.110505
# min       0.257400
# 25%       1.064171
# 50%       1.243148
# 75%       1.526159
# max       8.371554
# Name: Day +1, dtype: float64
# pharmaceuticals-biotech count    78.000000
# mean      1.901177
# std       1.482796
# min       0.442632
# 25%       1.020623
# 50%       1.456225
# 75%       2.226987
# max       8.066041
# Name: Day +1, dtype: float64
# healthcare count    102.000000
# mean       2.654354
# std        3.002894
# min        0.460180
# 25%        0.859419
# 50%        1.614108
# 75%        2.642379
# max       15.103362
# Name: Day +1, dtype: float64
# consumer-retailing count    11.000000
# mean      1.421049
# std       1.241541
# min       0.349327
# 25%       0.657232
# 50%       0.867530
# 75%       1.891160
# max       4.443690
# Name: Day +1, dtype: float64
# real-estate count    108.000000
# mean       0.868688
# std        1.118949
# min        0.246686
# 25%        0.484509
# 50%        0.601454
# 75%        0.835866
# max        8.512111
# Name: Day +1, dtype: float64
# capital-goods count    92.000000
# mean      1.529932
# std       2.057121
# min       0.389723
# 25%       0.741000
# 50%       0.918096
# 75%       1.393133
# max      13.173045
# Name: Day +1, dtype: float64
# retail count    76.000000
# mean      2.240978
# std       2.130008
# min       0.471717
# 25%       0.976207
# 50%       1.462880
# 75%       2.406306
# max      10.085085
# Name: Day +1, dtype: float64
# software count    80.000000
# mean      3.851838
# std       4.044539
# min       0.288526
# 25%       1.039779
# 50%       2.390836
# 75%       4.928965
# max      18.847661
# Name: Day +1, dtype: float64
# utilities count    33.000000
# mean      0.684753
# std       0.598116
# min       0.294285
# 25%       0.400692
# 50%       0.502872
# 75%       0.755118
# max       3.626234
# Name: Day +1, dtype: float64
# food-beverage-tobacco count    30.000000
# mean      1.748954
# std       2.484920
# min       0.399445
# 25%       0.687436
# 50%       0.966649
# 75%       1.587779
# max      13.345664
# Name: Day +1, dtype: float64
# telecom count    21.000000
# mean      1.844339
# std       1.445404
# min       0.364092
# 25%       0.960192
# 50%       1.214374
# 75%       2.853777
# max       5.981140
# Name: Day +1, dtype: float64
# automobiles count    23.000000
# mean      1.162688
# std       0.729208
# min       0.436181
# 25%       0.806389
# 50%       0.963745
# 75%       1.151995
# max       3.864870
# Name: Day +1, dtype: float64
# diversified-financials count    74.000000
# mean      1.715133
# std       3.404789
# min       0.220835
# 25%       0.663598
# 50%       0.882094
# 75%       1.457828
# max      26.972454
# Name: Day +1, dtype: float64
# consumer-durables count    72.000000
# mean      2.163698
# std       2.556281
# min       0.450172
# 25%       0.849589
# 50%       1.027836
# 75%       1.888575
# max      13.868194
# Name: Day +1, dtype: float64
# household count    19.000000
# mean      1.931393
# std       1.897371
# min       0.482551
# 25%       0.874446
# 50%       1.246390
# 75%       1.873290
# max       7.605972
# Name: Day +1, dtype: float64
# tech count    76.000000
# mean      1.985356
# std       1.712936
# min       0.505370
# 25%       0.914138
# 50%       1.541936
# 75%       2.285761
# max      11.350426
# Name: Day +1, dtype: float64
# banks count    104.000000
# mean       0.980184
# std        0.546051
# min        0.336588
# 25%        0.746234
# 50%        0.857510
# 75%        1.072589
# max        4.779409
# Name: Day +1, dtype: float64
# insurance count    45.000000
# mean      1.723659
# std       3.758222
# min       0.145400
# 25%       0.537818
# 50%       0.778103
# 75%       1.127436
# max      24.351941
# Name: Day +1, dtype: float64
# semiconductors count    48.000000
# mean      2.459550
# std       2.452836
# min       0.648851
# 25%       1.178058
# 50%       1.721506
# 75%       2.488998
# max      15.217382
# Name: Day +1, dtype: float64
# commercial-services count    63.000000
# mean      1.404846
# std       1.520454
# min       0.403533
# 25%       0.718827
# 50%       0.974075
# 75%       1.507743
# max      11.033142
# Name: Day +1, dtype: float64
# media count    68.000000
# mean      2.647266
# std       2.871509
# min       0.000000
# 25%       0.972005
# 50%       1.461700
# 75%       3.396664
# max      15.722992
# Name: Day +1, dtype: float64

# %%
inds_perc = pd.DataFrame(columns = ['Day +1', 'Day +2', 'Day +7', 'Day +28', 'Day +63'])
csv_file = 'statistical_data/' + 'software' + '/' + 'software' + '_price_perc.csv'

with open(csv_file, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        key = row.pop('')
        for a in row:
            row[a] = float(row[a])
        inds_perc.loc[key] = row

print(inds_perc)
# Out:
#         Day +1     Day +2     Day +7    Day +28    Day +63
# DXC   1.034003   3.382222   5.501011   6.823822   9.384537
# TENB  6.004739   7.682738   9.956450  14.218718  20.348916
# ESMT  2.458208   1.835900   7.676030  11.555466  10.827066
# CCCS  1.293284   4.215415   9.786304   6.757474   8.749839
# GWRE  1.897482   3.364249   4.402241   5.909805   8.692353
# ...        ...        ...        ...        ...        ...
# RNG   3.652802   5.982618   7.743854   9.435275  13.962908
# SQSP  4.782690   7.918694   6.431379  10.530074  21.295527
# APPN  3.996511   5.101206   8.966247  13.801412  18.187289
# MNDY  0.288526  10.819672  29.554103  20.613113  18.796717
# FOUR  0.883429   2.455254   0.757232   1.388250   8.581922
#
# [80 rows x 5 columns]

# %%
plt.hist(inds_perc['Day +1'], bins = 20)
plt.title('Price Percentage Change of Software Industry on Day +1')
plt.xlabel('Percentage Change In Price')
plt.ylabel('Number of Companies')
plt.savefig('statistical_data/software/software_price_perc_Day+1_hist.png')
#plt.show()

# %%
plt.hist(inds_perc['Day +7'], bins = 20)
plt.title('Price Percentage Change of Software Industry on Day +7')
plt.xlabel('Percentage Change In Price')
plt.ylabel('Number of Companies')
plt.savefig('statistical_data/software/software_price_perc_Day+7_hist.png')
#plt.show()

# %%
plt.hist(inds_perc['Day +63'], bins = 20)
plt.title('Price Percentage Change of Software Industry on Day +63')
plt.xlabel('Percentage Change In Price')
plt.ylabel('Number of Companies')
plt.savefig('statistical_data/software/software_price_perc_Day+63_hist.png')
#plt.show()

# %%
inds_perc = pd.DataFrame(columns = ['Day +1', 'Day +2', 'Day +7', 'Day +28', 'Day +63'])
csv_file = 'industry_percentage_statistics.csv'

with open(csv_file, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        key = row.pop('')
        for a in row:
            row[a] = float(row[a])
        inds_perc.loc[key] = row

print(inds_perc)
industry_percentage_statistics

# %% [markdown]
# New approach: identify companies that have low impact on first day and higher change on 1month~2month period

# %%
inds_perc_stat = pd.DataFrame(columns = ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'])

for inds in data:
    print('current industry: ' + inds)
    inds_perc = pd.DataFrame(columns = ['Day +1', 'Day +2', 'Day +7', 'Day +28', 'Day +63'])
    
    for cmp in data[inds]:
        print('current company: ' + cmp)
        cmp_perc = pd.DataFrame(columns = ['Day +1', 'Day +2', 'Day +7', 'Day +28', 'Day +63'])
        csv_file = 'statistical_data/' + inds + '/' + cmp + '/' + cmp + 'price_perc.csv'
        
        with open(csv_file, newline='') as csvfile:
            reader = csv.DictReader(csvfile)
    
            for row in reader:
                key = row.pop('')
                for a in row:
                    row[a] = float(row[a])
                
                cmp_perc.loc[key] = row
                
        print(cmp_perc)
        #get average day +1, day +7, day +28, day +63 values
        #check if 
        
        break
        
    break
# Out:
# current industry: transportation
# current company: SB
#                   Day +1     Day +2     Day +7    Day +28     Day +63
# 2012-08-07  3.278685e-01   0.000000  -1.147536   0.000000   -4.918028
# 2012-11-15 -1.092902e+00  -3.278692  -5.737706 -13.661202    5.464476
# 2013-02-21  5.361925e-01   6.166220   4.021450  32.975872   31.367294
# 2013-05-16  3.816881e-01   0.954202   3.244276   0.381688   -0.572514
# 2013-11-05 -1.184748e-01  -2.488152  -2.251180 -11.255922   19.075838
# 2014-11-12 -1.083031e+00  -6.137187  -0.541511 -25.090250  -31.949458
# 2015-07-31  1.744184e+00   4.941856   0.872092  -6.976744  -12.790699
# 2015-11-10 -3.124997e+00  -9.375002  -9.375002 -50.892856  -82.589286
# 2016-02-11  2.842171e-14  17.021279  31.914895  70.212769  134.042559
# 2016-06-03 -2.830186e+00   8.490570  11.320756   0.000000   20.754721
# 2016-07-30  0.000000e+00   6.422012  10.091744  18.348617   32.110093
# 2016-10-31 -3.149603e+00   0.000000  -3.149603  22.047242    0.787401
# 2017-02-24  7.462679e-01   4.477608  14.925367  34.328351   61.940300
# 2017-05-19  4.694831e-01   0.000000  -2.347427   9.389662   16.901403
# 2017-07-27 -2.074697e+00   0.829875   8.298747  19.917013   18.672191
# 2017-11-01  2.941174e-01   0.588235   5.588230  -8.529417    7.352941
# 2018-02-15 -1.643841e+00  -3.835619   3.287668   0.821917  -13.698630
# 2018-05-30  9.463713e-01  12.302835  22.082012  17.034699    7.886435
# 2018-07-27  6.309142e-01   7.570978   6.624607  -4.731864   -8.201892
# 2018-11-10  2.109713e+00  -5.485227  -8.438811 -16.877632  -18.987340
# 2019-02-19  0.000000e+00  -8.333333  -7.738095  -6.547613    1.190482
# 2019-05-28 -1.948050e+00  -4.545450  -9.090908  -5.844150   34.415583
# 2019-09-04  1.463413e+00   0.975609   1.463413 -17.560971  -13.170731
# 2020-06-09 -7.462679e-01  -5.223884  -2.985081  -9.701492   -8.208956
# 2020-08-06 -1.626015e+00   0.813007   2.439022 -11.382112  -13.008127
# 2021-05-08  4.999995e+00   4.999995  -4.000002  -7.499999  -11.750001
# 2021-11-04  9.615376e-01  -7.692306  -8.653844 -12.019225  -11.778841
# 2022-03-10  2.212387e+00   2.654865   2.654865 -12.831857  -11.061947
# 2022-07-28 -1.015227e+00  -4.568530  -4.568530  -9.644673  -37.817259

# %%
for inds in data:
    print(data[inds])
    break
# Out:
# ['SB', 'ULCC', 'PANL', 'AAL', 'RLGT', 'GNK', 'CAR', 'ARCB', 'CPA', 'DSKE', 'FWRD', 'WERN', 'TSP', 'SBLK', 'XPO', 'LYFT', 'SNCY', 'ULH', 'SKYW', 'JOBY', 'R', 'GOGL', 'ALK', 'KEX', 'ALGT', 'CHRW', 'LSTR', 'ZIM', 'NETI', 'KNX', 'UP', 'GSL', 'CMRE', 'HA', 'SNDR', 'YMM', 'HUBG', 'EGLE', 'DAC', 'GXO', 'SAVE', 'UHAL', 'MATX', 'JBLU', 'ATSG', 'DSX', 'CAAP', 'CVLG']
